# %%
from Bio import SeqIO
import Bio
from collections import defaultdict

class Vertex:
    
    def __init__(self, seq):
        self.seq = seq
        self.coverage = 1
        self.in_edges = {}
        self.out_edges = {}
        
    def increase_coverage(self):
        self.coverage += 1

class Edge:
    
    def __init__(self,k1,k2):
        self.seq = k1 + k2[-1]
        self.n = 2
        self.coverage = 0
    
    def calc_coverage(self,c1,c2):
        self.coverage = (c1+c2)/2


class Graph:

    def __init__(self,k):
        self.vertices = {}
        self.k = k
        
    def add_read(self,read):
        read_lng = len(read)
        if read_lng < self.k:
            return
            
        kmer = read[:k]
        if kmer in self.vertices:
            self.vertices[kmer].increase_coverage()
        else:
            self.vertices[kmer] = Vertex(kmer)
        
        for next_kmer_indx in range(1,read_lng-k+1,1):
            next_kmer = read[next_kmer_indx:(next_kmer_indx+k)]
            if next_kmer in self.vertices:
                self.vertices[next_kmer].increase_coverage()
            else:
                self.vertices[next_kmer] = Vertex(next_kmer)
            
            new_edge = Edge(kmer,next_kmer)
            self.vertices[next_kmer].in_edges[kmer]  = [new_edge]
            self.vertices[kmer].out_edges[next_kmer] = [new_edge]
            kmer = next_kmer
    
    def calc_init_edge_coverage(self):
        
        for current_vertex in self.vertices.keys():
            for next_vertex in self.vertices[current_vertex].out_edges.keys():
                self.vertices[current_vertex].out_edges[next_vertex][0].calc_coverage(self.vertices[current_vertex].coverage,self.vertices[next_vertex].coverage)
        
    def graph_visualization(self, path, full):
        
        self.graph =  Graph(comment='assembly')

        if full:
            for v, e in self.vertices.items():
                self.graph.node(v, label='{}'.format(v))
                
                for i, j in e.out_edges.items():
                    self.graph.edge(v, i,label='{}'.format(j[0].seq))

        else:
            for v, e in self.vertices.items():
                self.graph.node(v, label='coverage={}'.format(my_graph.vertices[v].coverage))
                
                for i, j in e.out_edges.items():
                    self.graph.edge(v, i,label='len={},cov={}'.format(len(j[0].seq), j[0].coverage))
        
        print(self.graph.source)
        with open (path, 'w') as handle:
            handle.write(self.graph.source)
        
       

if __name__ == '__main__':
    
    dataset = './hw_4_5_dataset.fasta'

    k = 5
    
    my_graph = Graph(k)
    direction = 'reverse'
    with open(dataset, "r") as handle:
        for record in SeqIO.parse(handle, "fasta"):
            if direction == 'reverse':
                read = str(record.reverse_complement().seq)
                my_graph.add_read(read)
            else:
                read = str(record.seq)
                my_graph.add_read(read)

    my_graph.calc_init_edge_coverage()
    
    for v in my_graph.vertices:
        print('Vertex: {}, coverage: {}'.format(v,my_graph.vertices[v].coverage))
        for e in my_graph.vertices[v].out_edges:
            print('-> Out edge: {}'.format(e))
        for e in my_graph.vertices[v].in_edges:
            print('-> In edge: {}'.format(e))            
    
    my_graph.graph_visualization('Graph.dot', full=False)
# Out:
# Vertex: GTGGT, coverage: 371
# -> Out edge: TGGTA
# -> Out edge: TGGTC
# -> Out edge: TGGTT
# -> Out edge: TGGTG
# -> In edge: GGTGG
# -> In edge: TGTGG
# -> In edge: CGTGG
# -> In edge: AGTGG
# Vertex: GAACT, coverage: 178
# -> Out edge: AACTG
# -> Out edge: AACTT
# -> Out edge: AACTC
# -> Out edge: AACTA
# -> In edge: CGAAC
# -> In edge: AGAAC
# -> In edge: TGAAC
# -> In edge: GGAAC
# Vertex: CTTGT, coverage: 548
# -> Out edge: TTGTA
# -> Out edge: TTGTG
# -> Out edge: TTGTC
# -> Out edge: TTGTT
# -> In edge: CCTTG
# -> In edge: TCTTG
# -> In edge: GCTTG
# -> In edge: ACTTG
# Vertex: GTTCG, coverage: 11
# -> Out edge: TTCGC
# -> Out edge: TTCGG
# -> Out edge: TTCGA
# -> Out edge: TTCGT
# -> In edge: CGTTC
# -> In edge: TGTTC
# -> In edge: GGTTC
# -> In edge: AGTTC
# Vertex: CTGAG, coverage: 663
# -> Out edge: TGAGG
# -> Out edge: TGAGC
# -> Out edge: TGAGT
# -> Out edge: TGAGA
# -> In edge: TCTGA
# -> In edge: ACTGA
# -> In edge: CCTGA
# -> In edge: GCTGA
# Vertex: CTTAG, coverage: 102
# -> Out edge: TTAGA
# -> Out edge: TTAGT
# -> Out edge: TTAGG
# -> Out edge: TTAGC
# -> In edge: CCTTA
# -> In edge: GCTTA
# -> In edge: TCTTA
# -> In edge: ACTTA
# Vertex: ACCGT, coverage: 7
# -> Out edge: CCGTT
# -> Out edge: CCGTA
# -> Out edge: CCGTC
# -> Out edge: CCGTG
# -> In edge: CACCG
# -> In edge: TACCG
# -> In edge: GACCG
# Vertex: GCCTC, coverage: 420
# -> Out edge: CCTCT
# -> Out edge: CCTCG
# -> Out edge: CCTCA
# -> Out edge: CCTCC
# -> In edge: TGCCT
# -> In edge: GGCCT
# -> In edge: CGCCT
# -> In edge: AGCCT
# Vertex: ACATA, coverage: 466
# -> Out edge: CATAT
# -> Out edge: CATAC
# -> Out edge: CATAA
# -> Out edge: CATAG
# -> In edge: GACAT
# -> In edge: AACAT
# -> In edge: CACAT
# -> In edge: TACAT
# Vertex: ACACA, coverage: 295
# -> Out edge: CACAT
# -> Out edge: CACAA
# -> Out edge: CACAG
# -> Out edge: CACAC
# -> In edge: TACAC
# -> In edge: AACAC
# -> In edge: GACAC
# -> In edge: CACAC
# Vertex: GTTCA, coverage: 372
# -> Out edge: TTCAC
# -> Out edge: TTCAT
# -> Out edge: TTCAA
# -> Out edge: TTCAG
# -> In edge: TGTTC
# -> In edge: AGTTC
# -> In edge: GGTTC
# -> In edge: CGTTC
# Vertex: CGTTC, coverage: 105
# -> Out edge: GTTCT
# -> Out edge: GTTCG
# -> Out edge: GTTCA
# -> Out edge: GTTCC
# -> In edge: CCGTT
# -> In edge: TCGTT
# -> In edge: ACGTT
# -> In edge: GCGTT
# Vertex: GTAAT, coverage: 99
# -> Out edge: TAATA
# -> Out edge: TAATT
# -> Out edge: TAATG
# -> Out edge: TAATC
# -> In edge: AGTAA
# -> In edge: CGTAA
# -> In edge: TGTAA
# -> In edge: GGTAA
# Vertex: GTCCG, coverage: 465
# -> Out edge: TCCGG
# -> Out edge: TCCGT
# -> Out edge: TCCGC
# -> Out edge: TCCGA
# -> In edge: AGTCC
# -> In edge: GGTCC
# -> In edge: TGTCC
# -> In edge: CGTCC
# Vertex: TAGGT, coverage: 104
# -> Out edge: AGGTC
# -> Out edge: AGGTG
# -> Out edge: AGGTA
# -> Out edge: AGGTT
# -> In edge: TTAGG
# -> In edge: CTAGG
# -> In edge: GTAGG
# -> In edge: ATAGG
# Vertex: CCCCT, coverage: 107
# -> Out edge: CCCTA
# -> Out edge: CCCTC
# -> Out edge: CCCTT
# -> Out edge: CCCTG
# -> In edge: GCCCC
# -> In edge: TCCCC
# -> In edge: ACCCC
# -> In edge: CCCCC
# Vertex: CCTAT, coverage: 7
# -> Out edge: CTATC
# -> Out edge: CTATT
# -> Out edge: CTATG
# -> Out edge: CTATA
# -> In edge: CCCTA
# -> In edge: ACCTA
# -> In edge: GCCTA
# -> In edge: TCCTA
# Vertex: TCAAG, coverage: 198
# -> Out edge: CAAGC
# -> Out edge: CAAGT
# -> Out edge: CAAGA
# -> Out edge: CAAGG
# -> In edge: GTCAA
# -> In edge: CTCAA
# -> In edge: ATCAA
# -> In edge: TTCAA
# Vertex: GCAGA, coverage: 681
# -> Out edge: CAGAC
# -> Out edge: CAGAT
# -> Out edge: CAGAG
# -> Out edge: CAGAA
# -> In edge: AGCAG
# -> In edge: GGCAG
# -> In edge: TGCAG
# -> In edge: CGCAG
# Vertex: GTTAG, coverage: 101
# -> Out edge: TTAGG
# -> Out edge: TTAGA
# -> Out edge: TTAGC
# -> Out edge: TTAGT
# -> In edge: TGTTA
# -> In edge: CGTTA
# -> In edge: GGTTA
# -> In edge: AGTTA
# Vertex: GGCAT, coverage: 468
# -> Out edge: GCATT
# -> Out edge: GCATA
# -> Out edge: GCATG
# -> Out edge: GCATC
# -> In edge: CGGCA
# -> In edge: GGGCA
# -> In edge: AGGCA
# -> In edge: TGGCA
# Vertex: CTAAA, coverage: 106
# -> Out edge: TAAAA
# -> Out edge: TAAAG
# -> Out edge: TAAAC
# -> Out edge: TAAAT
# -> In edge: CCTAA
# -> In edge: GCTAA
# -> In edge: TCTAA
# -> In edge: ACTAA
# Vertex: GCAGT, coverage: 387
# -> Out edge: CAGTA
# -> Out edge: CAGTG
# -> Out edge: CAGTC
# -> Out edge: CAGTT
# -> In edge: AGCAG
# -> In edge: GGCAG
# -> In edge: TGCAG
# -> In edge: CGCAG
# Vertex: TCTTA, coverage: 196
# -> Out edge: CTTAA
# -> Out edge: CTTAG
# -> Out edge: CTTAT
# -> Out edge: CTTAC
# -> In edge: CTCTT
# -> In edge: TTCTT
# -> In edge: GTCTT
# Vertex: AGTCC, coverage: 831
# -> Out edge: GTCCG
# -> Out edge: GTCCT
# -> Out edge: GTCCA
# -> Out edge: GTCCC
# -> In edge: TAGTC
# -> In edge: CAGTC
# -> In edge: GAGTC
# -> In edge: AAGTC
# Vertex: CGTCG, coverage: 108
# -> Out edge: GTCGG
# -> Out edge: GTCGT
# -> Out edge: GTCGA
# -> Out edge: GTCGC
# -> In edge: ACGTC
# -> In edge: TCGTC
# -> In edge: GCGTC
# -> In edge: CCGTC
# Vertex: AATCC, coverage: 377
# -> Out edge: ATCCT
# -> Out edge: ATCCG
# -> Out edge: ATCCC
# -> Out edge: ATCCA
# -> In edge: GAATC
# -> In edge: CAATC
# -> In edge: AAATC
# -> In edge: TAATC
# Vertex: CCACG, coverage: 197
# -> Out edge: CACGT
# -> Out edge: CACGA
# -> Out edge: CACGG
# -> Out edge: CACGC
# -> In edge: TCCAC
# -> In edge: ACCAC
# -> In edge: GCCAC
# -> In edge: CCCAC
# Vertex: GGCAC, coverage: 372
# -> Out edge: GCACT
# -> Out edge: GCACC
# -> Out edge: GCACG
# -> Out edge: GCACA
# -> In edge: GGGCA
# -> In edge: CGGCA
# -> In edge: TGGCA
# -> In edge: AGGCA
# Vertex: TGATC, coverage: 25
# -> Out edge: GATCT
# -> Out edge: GATCC
# -> Out edge: GATCG
# -> Out edge: GATCA
# -> In edge: ATGAT
# -> In edge: GTGAT
# -> In edge: TTGAT
# -> In edge: CTGAT
# Vertex: CTGCC, coverage: 244
# -> Out edge: TGCCT
# -> Out edge: TGCCC
# -> Out edge: TGCCA
# -> In edge: TCTGC
# -> In edge: ACTGC
# -> In edge: CCTGC
# -> In edge: GCTGC
# Vertex: CTCTC, coverage: 138
# -> Out edge: TCTCG
# -> Out edge: TCTCA
# -> Out edge: TCTCC
# -> Out edge: TCTCT
# -> In edge: TCTCT
# -> In edge: CCTCT
# -> In edge: ACTCT
# -> In edge: GCTCT
# Vertex: GAACA, coverage: 464
# -> Out edge: AACAA
# -> Out edge: AACAT
# -> Out edge: AACAC
# -> Out edge: AACAG
# -> In edge: CGAAC
# -> In edge: AGAAC
# -> In edge: TGAAC
# -> In edge: GGAAC
# Vertex: TAATA, coverage: 380
# -> Out edge: AATAA
# -> Out edge: AATAC
# -> Out edge: AATAT
# -> Out edge: AATAG
# -> In edge: GTAAT
# -> In edge: ATAAT
# -> In edge: CTAAT
# -> In edge: TTAAT
# Vertex: GCCAT, coverage: 96
# -> Out edge: CCATC
# -> Out edge: CCATA
# -> Out edge: CCATT
# -> Out edge: CCATG
# -> In edge: AGCCA
# -> In edge: CGCCA
# -> In edge: GGCCA
# Vertex: AATGA, coverage: 394
# -> Out edge: ATGAT
# -> Out edge: ATGAC
# -> Out edge: ATGAA
# -> Out edge: ATGAG
# -> In edge: AAATG
# -> In edge: TAATG
# -> In edge: GAATG
# -> In edge: CAATG
# Vertex: TAAAG, coverage: 482
# -> Out edge: AAAGC
# -> Out edge: AAAGT
# -> Out edge: AAAGG
# -> Out edge: AAAGA
# -> In edge: CTAAA
# -> In edge: GTAAA
# -> In edge: ATAAA
# -> In edge: TTAAA
# Vertex: GCATT, coverage: 108
# -> Out edge: CATTA
# -> Out edge: CATTC
# -> Out edge: CATTT
# -> Out edge: CATTG
# -> In edge: CGCAT
# -> In edge: AGCAT
# -> In edge: GGCAT
# Vertex: CTGTG, coverage: 101
# -> Out edge: TGTGT
# -> Out edge: TGTGG
# -> Out edge: TGTGC
# -> Out edge: TGTGA
# -> In edge: ACTGT
# -> In edge: CCTGT
# -> In edge: GCTGT
# -> In edge: TCTGT
# Vertex: TCTAA, coverage: 284
# -> Out edge: CTAAG
# -> Out edge: CTAAT
# -> Out edge: CTAAC
# -> Out edge: CTAAA
# -> In edge: CTCTA
# -> In edge: ATCTA
# -> In edge: TTCTA
# -> In edge: GTCTA
# Vertex: CTGGA, coverage: 637
# -> Out edge: TGGAT
# -> Out edge: TGGAA
# -> Out edge: TGGAG
# -> Out edge: TGGAC
# -> In edge: TCTGG
# -> In edge: GCTGG
# -> In edge: CCTGG
# -> In edge: ACTGG
# Vertex: AACTT, coverage: 109
# -> Out edge: ACTTC
# -> Out edge: ACTTG
# -> Out edge: ACTTT
# -> In edge: GAACT
# -> In edge: AAACT
# -> In edge: TAACT
# -> In edge: CAACT
# Vertex: CGACG, coverage: 272
# -> Out edge: GACGG
# -> Out edge: GACGA
# -> Out edge: GACGC
# -> Out edge: GACGT
# -> In edge: CCGAC
# -> In edge: GCGAC
# -> In edge: TCGAC
# Vertex: CTAGG, coverage: 374
# -> Out edge: TAGGC
# -> Out edge: TAGGT
# -> Out edge: TAGGG
# -> Out edge: TAGGA
# -> In edge: CCTAG
# -> In edge: ACTAG
# -> In edge: TCTAG
# -> In edge: GCTAG
# Vertex: GAGCT, coverage: 108
# -> Out edge: AGCTT
# -> Out edge: AGCTC
# -> Out edge: AGCTG
# -> Out edge: AGCTA
# -> In edge: TGAGC
# -> In edge: CGAGC
# -> In edge: GGAGC
# -> In edge: AGAGC
# Vertex: GCCAG, coverage: 288
# -> Out edge: CCAGA
# -> Out edge: CCAGG
# -> Out edge: CCAGC
# -> Out edge: CCAGT
# -> In edge: AGCCA
# -> In edge: CGCCA
# -> In edge: TGCCA
# -> In edge: GGCCA
# Vertex: ACCAA, coverage: 383
# -> Out edge: CCAAT
# -> Out edge: CCAAC
# -> Out edge: CCAAG
# -> Out edge: CCAAA
# -> In edge: TACCA
# -> In edge: AACCA
# -> In edge: GACCA
# -> In edge: CACCA
# Vertex: GCCCT, coverage: 191
# -> Out edge: CCCTA
# -> Out edge: CCCTC
# -> Out edge: CCCTT
# -> Out edge: CCCTG
# -> In edge: CGCCC
# -> In edge: GGCCC
# -> In edge: TGCCC
# -> In edge: AGCCC
# Vertex: CACTA, coverage: 100
# -> Out edge: ACTAG
# -> Out edge: ACTAC
# -> Out edge: ACTAT
# -> Out edge: ACTAA
# -> In edge: GCACT
# -> In edge: ACACT
# -> In edge: CCACT
# -> In edge: TCACT
# Vertex: GAAGC, coverage: 117
# -> Out edge: AAGCG
# -> Out edge: AAGCC
# -> Out edge: AAGCT
# -> Out edge: AAGCA
# -> In edge: AGAAG
# -> In edge: TGAAG
# -> In edge: CGAAG
# -> In edge: GGAAG
# Vertex: CTCCA, coverage: 647
# -> Out edge: TCCAC
# -> Out edge: TCCAA
# -> Out edge: TCCAT
# -> Out edge: TCCAG
# -> In edge: CCTCC
# -> In edge: ACTCC
# -> In edge: GCTCC
# -> In edge: TCTCC
# Vertex: GTCGA, coverage: 103
# -> Out edge: TCGAT
# -> Out edge: TCGAG
# -> Out edge: TCGAA
# -> Out edge: TCGAC
# -> In edge: CGTCG
# -> In edge: TGTCG
# -> In edge: GGTCG
# -> In edge: AGTCG
# Vertex: TAAAA, coverage: 568
# -> Out edge: AAAAT
# -> Out edge: AAAAG
# -> Out edge: AAAAC
# -> Out edge: AAAAA
# -> In edge: TTAAA
# -> In edge: GTAAA
# -> In edge: ATAAA
# -> In edge: CTAAA
# Vertex: TCACA, coverage: 102
# -> Out edge: CACAT
# -> Out edge: CACAA
# -> Out edge: CACAG
# -> Out edge: CACAC
# -> In edge: ATCAC
# -> In edge: GTCAC
# -> In edge: CTCAC
# -> In edge: TTCAC
# Vertex: GTACG, coverage: 10
# -> Out edge: TACGG
# -> Out edge: TACGA
# -> Out edge: TACGT
# -> Out edge: TACGC
# -> In edge: CGTAC
# -> In edge: AGTAC
# -> In edge: GGTAC
# Vertex: AGAGG, coverage: 945
# -> Out edge: GAGGA
# -> Out edge: GAGGT
# -> Out edge: GAGGC
# -> Out edge: GAGGG
# -> In edge: AAGAG
# -> In edge: TAGAG
# -> In edge: CAGAG
# -> In edge: GAGAG
# Vertex: GCTAA, coverage: 15
# -> Out edge: CTAAG
# -> Out edge: CTAAT
# -> Out edge: CTAAC
# -> Out edge: CTAAA
# -> In edge: TGCTA
# -> In edge: CGCTA
# -> In edge: GGCTA
# -> In edge: AGCTA
# Vertex: GGTGC, coverage: 396
# -> Out edge: GTGCA
# -> Out edge: GTGCG
# -> Out edge: GTGCC
# -> Out edge: GTGCT
# -> In edge: CGGTG
# -> In edge: GGGTG
# -> In edge: AGGTG
# -> In edge: TGGTG
# Vertex: ATTCC, coverage: 115
# -> Out edge: TTCCC
# -> Out edge: TTCCG
# -> Out edge: TTCCA
# -> Out edge: TTCCT
# -> In edge: AATTC
# -> In edge: TATTC
# -> In edge: GATTC
# -> In edge: CATTC
# Vertex: CAGGG, coverage: 247
# -> Out edge: AGGGA
# -> Out edge: AGGGT
# -> Out edge: AGGGG
# -> Out edge: AGGGC
# -> In edge: TCAGG
# -> In edge: CCAGG
# -> In edge: ACAGG
# -> In edge: GCAGG
# Vertex: TCAGG, coverage: 195
# -> Out edge: CAGGT
# -> Out edge: CAGGG
# -> Out edge: CAGGA
# -> Out edge: CAGGC
# -> In edge: GTCAG
# -> In edge: ATCAG
# -> In edge: CTCAG
# -> In edge: TTCAG
# Vertex: CACAT, coverage: 377
# -> Out edge: ACATT
# -> Out edge: ACATG
# -> Out edge: ACATC
# -> Out edge: ACATA
# -> In edge: TCACA
# -> In edge: CCACA
# -> In edge: ACACA
# -> In edge: GCACA
# Vertex: TTAGC, coverage: 9
# -> Out edge: TAGCG
# -> Out edge: TAGCC
# -> Out edge: TAGCT
# -> Out edge: TAGCA
# -> In edge: GTTAG
# -> In edge: ATTAG
# -> In edge: CTTAG
# -> In edge: TTTAG
# Vertex: CCTTT, coverage: 189
# -> Out edge: CTTTC
# -> Out edge: CTTTG
# -> Out edge: CTTTA
# -> In edge: TCCTT
# -> In edge: GCCTT
# -> In edge: ACCTT
# Vertex: ATGCG, coverage: 202
# -> Out edge: TGCGG
# -> Out edge: TGCGA
# -> Out edge: TGCGC
# -> Out edge: TGCGT
# -> In edge: AATGC
# -> In edge: GATGC
# -> In edge: TATGC
# -> In edge: CATGC
# Vertex: GCGTC, coverage: 198
# -> Out edge: CGTCG
# -> Out edge: CGTCT
# -> Out edge: CGTCA
# -> Out edge: CGTCC
# -> In edge: AGCGT
# -> In edge: CGCGT
# -> In edge: TGCGT
# -> In edge: GGCGT
# Vertex: AATTC, coverage: 198
# -> Out edge: ATTCT
# -> Out edge: ATTCG
# -> Out edge: ATTCC
# -> Out edge: ATTCA
# -> In edge: CAATT
# -> In edge: GAATT
# -> In edge: AAATT
# -> In edge: TAATT
# Vertex: CCAGA, coverage: 293
# -> Out edge: CAGAC
# -> Out edge: CAGAT
# -> Out edge: CAGAG
# -> Out edge: CAGAA
# -> In edge: ACCAG
# -> In edge: GCCAG
# -> In edge: CCCAG
# -> In edge: TCCAG
# Vertex: GGCGC, coverage: 101
# -> Out edge: GCGCA
# -> Out edge: GCGCT
# -> Out edge: GCGCG
# -> Out edge: GCGCC
# -> In edge: CGGCG
# -> In edge: TGGCG
# -> In edge: GGGCG
# -> In edge: AGGCG
# Vertex: AACGG, coverage: 369
# -> Out edge: ACGGC
# -> Out edge: ACGGG
# -> Out edge: ACGGA
# -> Out edge: ACGGT
# -> In edge: TAACG
# -> In edge: AAACG
# -> In edge: GAACG
# -> In edge: CAACG
# Vertex: CAGAC, coverage: 640
# -> Out edge: AGACG
# -> Out edge: AGACA
# -> Out edge: AGACT
# -> Out edge: AGACC
# -> In edge: GCAGA
# -> In edge: CCAGA
# -> In edge: ACAGA
# -> In edge: TCAGA
# Vertex: AAACT, coverage: 206
# -> Out edge: AACTG
# -> Out edge: AACTT
# -> Out edge: AACTC
# -> Out edge: AACTA
# -> In edge: CAAAC
# -> In edge: AAAAC
# -> In edge: GAAAC
# -> In edge: TAAAC
# Vertex: ATGAG, coverage: 488
# -> Out edge: TGAGG
# -> Out edge: TGAGC
# -> Out edge: TGAGT
# -> Out edge: TGAGA
# -> In edge: AATGA
# -> In edge: GATGA
# -> In edge: CATGA
# -> In edge: TATGA
# Vertex: ACTCA, coverage: 103
# -> Out edge: CTCAT
# -> Out edge: CTCAA
# -> Out edge: CTCAC
# -> Out edge: CTCAG
# -> In edge: AACTC
# -> In edge: CACTC
# -> In edge: TACTC
# -> In edge: GACTC
# Vertex: TTATG, coverage: 285
# -> Out edge: TATGT
# -> Out edge: TATGG
# -> Out edge: TATGC
# -> Out edge: TATGA
# -> In edge: ATTAT
# -> In edge: TTTAT
# -> In edge: CTTAT
# -> In edge: GTTAT
# Vertex: CCCCG, coverage: 296
# -> Out edge: CCCGC
# -> Out edge: CCCGT
# -> Out edge: CCCGA
# -> Out edge: CCCGG
# -> In edge: GCCCC
# -> In edge: TCCCC
# -> In edge: ACCCC
# -> In edge: CCCCC
# Vertex: CCATT, coverage: 17
# -> Out edge: CATTA
# -> Out edge: CATTC
# -> Out edge: CATTT
# -> Out edge: CATTG
# -> In edge: ACCAT
# -> In edge: TCCAT
# -> In edge: GCCAT
# -> In edge: CCCAT
# Vertex: TTCGC, coverage: 8
# -> Out edge: TCGCG
# -> Out edge: TCGCT
# -> Out edge: TCGCC
# -> Out edge: TCGCA
# -> In edge: TTTCG
# -> In edge: ATTCG
# -> In edge: CTTCG
# -> In edge: GTTCG
# Vertex: GCTGA, coverage: 379
# -> Out edge: CTGAC
# -> Out edge: CTGAG
# -> Out edge: CTGAA
# -> Out edge: CTGAT
# -> In edge: AGCTG
# -> In edge: TGCTG
# -> In edge: GGCTG
# -> In edge: CGCTG
# Vertex: ATAGT, coverage: 195
# -> Out edge: TAGTC
# -> Out edge: TAGTA
# -> Out edge: TAGTG
# -> Out edge: TAGTT
# -> In edge: GATAG
# -> In edge: CATAG
# -> In edge: AATAG
# Vertex: CACGT, coverage: 8
# -> Out edge: ACGTC
# -> Out edge: ACGTG
# -> Out edge: ACGTA
# -> Out edge: ACGTT
# -> In edge: CCACG
# -> In edge: ACACG
# -> In edge: TCACG
# -> In edge: GCACG
# Vertex: GTTCT, coverage: 388
# -> Out edge: TTCTG
# -> Out edge: TTCTT
# -> Out edge: TTCTC
# -> Out edge: TTCTA
# -> In edge: CGTTC
# -> In edge: TGTTC
# -> In edge: GGTTC
# -> In edge: AGTTC
# Vertex: CGTCA, coverage: 99
# -> Out edge: GTCAG
# -> Out edge: GTCAA
# -> In edge: ACGTC
# -> In edge: TCGTC
# -> In edge: GCGTC
# -> In edge: CCGTC
# Vertex: GGGTT, coverage: 281
# -> Out edge: GGTTG
# -> Out edge: GGTTC
# -> Out edge: GGTTA
# -> Out edge: GGTTT
# -> In edge: TGGGT
# -> In edge: AGGGT
# -> In edge: GGGGT
# -> In edge: CGGGT
# Vertex: TGGAC, coverage: 11
# -> Out edge: GGACA
# -> Out edge: GGACG
# -> Out edge: GGACT
# -> In edge: GTGGA
# -> In edge: CTGGA
# Vertex: ATAGA, coverage: 205
# -> Out edge: TAGAA
# -> Out edge: TAGAG
# -> Out edge: TAGAT
# -> Out edge: TAGAC
# -> In edge: GATAG
# -> In edge: AATAG
# -> In edge: TATAG
# -> In edge: CATAG
# Vertex: ATTGA, coverage: 659
# -> Out edge: TTGAG
# -> Out edge: TTGAA
# -> Out edge: TTGAT
# -> Out edge: TTGAC
# -> In edge: GATTG
# -> In edge: AATTG
# -> In edge: CATTG
# -> In edge: TATTG
# Vertex: TACTG, coverage: 177
# -> Out edge: ACTGT
# -> Out edge: ACTGA
# -> Out edge: ACTGG
# -> Out edge: ACTGC
# -> In edge: TTACT
# -> In edge: GTACT
# -> In edge: CTACT
# -> In edge: ATACT
# Vertex: CAGGT, coverage: 562
# -> Out edge: AGGTC
# -> Out edge: AGGTG
# -> Out edge: AGGTA
# -> Out edge: AGGTT
# -> In edge: TCAGG
# -> In edge: ACAGG
# -> In edge: CCAGG
# -> In edge: GCAGG
# Vertex: GGGCT, coverage: 192
# -> Out edge: GGCTT
# -> Out edge: GGCTG
# -> Out edge: GGCTA
# -> Out edge: GGCTC
# -> In edge: CGGGC
# -> In edge: TGGGC
# -> In edge: GGGGC
# -> In edge: AGGGC
# Vertex: AAGGG, coverage: 666
# -> Out edge: AGGGA
# -> Out edge: AGGGG
# -> Out edge: AGGGT
# -> Out edge: AGGGC
# -> In edge: GAAGG
# -> In edge: TAAGG
# -> In edge: CAAGG
# -> In edge: AAAGG
# Vertex: ATTAT, coverage: 9
# -> Out edge: TTATG
# -> Out edge: TTATT
# -> Out edge: TTATA
# -> Out edge: TTATC
# -> In edge: GATTA
# -> In edge: CATTA
# -> In edge: TATTA
# -> In edge: AATTA
# Vertex: TTGTC, coverage: 102
# -> Out edge: TGTCT
# -> Out edge: TGTCC
# -> Out edge: TGTCG
# -> Out edge: TGTCA
# -> In edge: ATTGT
# -> In edge: GTTGT
# -> In edge: CTTGT
# -> In edge: TTTGT
# Vertex: CTTAT, coverage: 378
# -> Out edge: TTATG
# -> Out edge: TTATT
# -> Out edge: TTATA
# -> Out edge: TTATC
# -> In edge: CCTTA
# -> In edge: GCTTA
# -> In edge: TCTTA
# Vertex: TGCCG, coverage: 106
# -> Out edge: GCCGC
# -> Out edge: GCCGA
# -> Out edge: GCCGG
# -> Out edge: GCCGT
# -> In edge: GTGCC
# -> In edge: ATGCC
# -> In edge: TTGCC
# Vertex: GCATA, coverage: 288
# -> Out edge: CATAT
# -> Out edge: CATAC
# -> Out edge: CATAA
# -> Out edge: CATAG
# -> In edge: CGCAT
# -> In edge: TGCAT
# -> In edge: GGCAT
# -> In edge: AGCAT
# Vertex: CTGGG, coverage: 45
# -> Out edge: TGGGA
# -> Out edge: TGGGT
# -> Out edge: TGGGG
# -> In edge: TCTGG
# -> In edge: GCTGG
# -> In edge: CCTGG
# -> In edge: ACTGG
# Vertex: TTGTT, coverage: 750
# -> Out edge: TGTTA
# -> Out edge: TGTTC
# -> Out edge: TGTTG
# -> Out edge: TGTTT
# -> In edge: ATTGT
# -> In edge: GTTGT
# -> In edge: CTTGT
# -> In edge: TTTGT
# Vertex: GGGTG, coverage: 112
# -> Out edge: GGTGG
# -> Out edge: GGTGT
# -> Out edge: GGTGC
# -> Out edge: GGTGA
# -> In edge: TGGGT
# -> In edge: AGGGT
# -> In edge: GGGGT
# -> In edge: CGGGT
# Vertex: CATGT, coverage: 101
# -> Out edge: ATGTC
# -> Out edge: ATGTT
# -> Out edge: ATGTA
# -> Out edge: ATGTG
# -> In edge: TCATG
# -> In edge: GCATG
# -> In edge: ACATG
# -> In edge: CCATG
# Vertex: GAGAC, coverage: 330
# -> Out edge: AGACG
# -> Out edge: AGACA
# -> Out edge: AGACT
# -> Out edge: AGACC
# -> In edge: GGAGA
# -> In edge: AGAGA
# -> In edge: CGAGA
# -> In edge: TGAGA
# Vertex: CCTTC, coverage: 248
# -> Out edge: CTTCA
# -> Out edge: CTTCT
# -> Out edge: CTTCC
# -> Out edge: CTTCG
# -> In edge: TCCTT
# -> In edge: GCCTT
# -> In edge: ACCTT
# -> In edge: CCCTT
# Vertex: TTCTG, coverage: 291
# -> Out edge: TCTGC
# -> Out edge: TCTGA
# -> Out edge: TCTGT
# -> Out edge: TCTGG
# -> In edge: ATTCT
# -> In edge: CTTCT
# -> In edge: GTTCT
# -> In edge: TTTCT
# Vertex: GCCGT, coverage: 103
# -> Out edge: CCGTT
# -> Out edge: CCGTA
# -> Out edge: CCGTC
# -> Out edge: CCGTG
# -> In edge: TGCCG
# -> In edge: CGCCG
# -> In edge: GGCCG
# -> In edge: AGCCG
# Vertex: ACTAA, coverage: 106
# -> Out edge: CTAAG
# -> Out edge: CTAAT
# -> Out edge: CTAAC
# -> Out edge: CTAAA
# -> In edge: GACTA
# -> In edge: TACTA
# -> In edge: CACTA
# -> In edge: AACTA
# Vertex: GCTTA, coverage: 98
# -> Out edge: CTTAA
# -> Out edge: CTTAG
# -> Out edge: CTTAT
# -> Out edge: CTTAC
# -> In edge: GGCTT
# -> In edge: TGCTT
# -> In edge: CGCTT
# Vertex: TGTAA, coverage: 561
# -> Out edge: GTAAC
# -> Out edge: GTAAA
# -> Out edge: GTAAG
# -> Out edge: GTAAT
# -> In edge: CTGTA
# -> In edge: TTGTA
# -> In edge: ATGTA
# -> In edge: GTGTA
# Vertex: CACCC, coverage: 386
# -> Out edge: ACCCT
# -> Out edge: ACCCA
# -> Out edge: ACCCG
# -> Out edge: ACCCC
# -> In edge: ACACC
# -> In edge: CCACC
# -> In edge: TCACC
# -> In edge: GCACC
# Vertex: AAAAC, coverage: 663
# -> Out edge: AAACG
# -> Out edge: AAACA
# -> Out edge: AAACT
# -> Out edge: AAACC
# -> In edge: TAAAA
# -> In edge: GAAAA
# -> In edge: CAAAA
# -> In edge: AAAAA
# Vertex: TTTGG, coverage: 669
# -> Out edge: TTGGC
# -> Out edge: TTGGT
# -> Out edge: TTGGA
# -> Out edge: TTGGG
# -> In edge: TTTTG
# -> In edge: CTTTG
# -> In edge: ATTTG
# -> In edge: GTTTG
# Vertex: TTGGG, coverage: 298
# -> Out edge: TGGGA
# -> Out edge: TGGGT
# -> Out edge: TGGGG
# -> Out edge: TGGGC
# -> In edge: GTTGG
# -> In edge: CTTGG
# -> In edge: ATTGG
# -> In edge: TTTGG
# Vertex: TAGCA, coverage: 192
# -> Out edge: AGCAG
# -> Out edge: AGCAC
# -> Out edge: AGCAT
# -> Out edge: AGCAA
# -> In edge: CTAGC
# -> In edge: TTAGC
# -> In edge: GTAGC
# -> In edge: ATAGC
# Vertex: ACTAG, coverage: 277
# -> Out edge: CTAGA
# -> Out edge: CTAGG
# -> Out edge: CTAGC
# -> Out edge: CTAGT
# -> In edge: GACTA
# -> In edge: TACTA
# -> In edge: CACTA
# -> In edge: AACTA
# Vertex: CCTCG, coverage: 196
# -> Out edge: CTCGA
# -> Out edge: CTCGG
# -> Out edge: CTCGT
# -> Out edge: CTCGC
# -> In edge: TCCTC
# -> In edge: GCCTC
# -> In edge: ACCTC
# -> In edge: CCCTC
# Vertex: CGCCT, coverage: 190
# -> Out edge: GCCTC
# -> Out edge: GCCTT
# -> Out edge: GCCTA
# -> Out edge: GCCTG
# -> In edge: GCGCC
# -> In edge: ACGCC
# -> In edge: TCGCC
# -> In edge: CCGCC
# Vertex: GGCGT, coverage: 197
# -> Out edge: GCGTA
# -> Out edge: GCGTG
# -> Out edge: GCGTC
# -> Out edge: GCGTT
# -> In edge: CGGCG
# -> In edge: TGGCG
# -> In edge: AGGCG
# -> In edge: GGGCG
# Vertex: GACGC, coverage: 192
# -> Out edge: ACGCC
# -> Out edge: ACGCT
# -> Out edge: ACGCA
# -> Out edge: ACGCG
# -> In edge: AGACG
# -> In edge: GGACG
# -> In edge: TGACG
# -> In edge: CGACG
# Vertex: TCAAC, coverage: 195
# -> Out edge: CAACA
# -> Out edge: CAACT
# -> Out edge: CAACG
# -> In edge: GTCAA
# -> In edge: ATCAA
# -> In edge: TTCAA
# Vertex: GGCGG, coverage: 184
# -> Out edge: GCGGT
# -> Out edge: GCGGA
# -> Out edge: GCGGC
# -> Out edge: GCGGG
# -> In edge: CGGCG
# -> In edge: TGGCG
# -> In edge: GGGCG
# -> In edge: AGGCG
# Vertex: AGGTA, coverage: 301
# -> Out edge: GGTAT
# -> Out edge: GGTAC
# -> Out edge: GGTAA
# -> Out edge: GGTAG
# -> In edge: CAGGT
# -> In edge: AAGGT
# -> In edge: TAGGT
# -> In edge: GAGGT
# Vertex: GCAGG, coverage: 784
# -> Out edge: CAGGT
# -> Out edge: CAGGG
# -> Out edge: CAGGA
# -> Out edge: CAGGC
# -> In edge: AGCAG
# -> In edge: GGCAG
# -> In edge: TGCAG
# -> In edge: CGCAG
# Vertex: GTACC, coverage: 14
# -> Out edge: TACCG
# -> Out edge: TACCA
# -> Out edge: TACCT
# -> Out edge: TACCC
# -> In edge: CGTAC
# -> In edge: AGTAC
# -> In edge: GGTAC
# Vertex: ATTTG, coverage: 564
# -> Out edge: TTTGC
# -> Out edge: TTTGA
# -> Out edge: TTTGT
# -> Out edge: TTTGG
# -> In edge: TATTT
# -> In edge: CATTT
# -> In edge: GATTT
# -> In edge: AATTT
# Vertex: GAATT, coverage: 386
# -> Out edge: AATTG
# -> Out edge: AATTT
# -> Out edge: AATTC
# -> Out edge: AATTA
# -> In edge: GGAAT
# -> In edge: TGAAT
# -> In edge: AGAAT
# -> In edge: CGAAT
# Vertex: TAGAG, coverage: 471
# -> Out edge: AGAGA
# -> Out edge: AGAGC
# -> Out edge: AGAGT
# -> Out edge: AGAGG
# -> In edge: CTAGA
# -> In edge: TTAGA
# -> In edge: ATAGA
# -> In edge: GTAGA
# Vertex: GTTTA, coverage: 374
# -> Out edge: TTTAC
# -> Out edge: TTTAA
# -> Out edge: TTTAT
# -> Out edge: TTTAG
# -> In edge: AGTTT
# -> In edge: TGTTT
# -> In edge: CGTTT
# -> In edge: GGTTT
# Vertex: CCGTA, coverage: 16
# -> Out edge: CGTAC
# -> Out edge: CGTAT
# -> Out edge: CGTAA
# -> Out edge: CGTAG
# -> In edge: TCCGT
# -> In edge: ACCGT
# -> In edge: GCCGT
# -> In edge: CCCGT
# Vertex: AGGGA, coverage: 437
# -> Out edge: GGGAA
# -> Out edge: GGGAG
# -> Out edge: GGGAT
# -> Out edge: GGGAC
# -> In edge: GAGGG
# -> In edge: AAGGG
# -> In edge: CAGGG
# -> In edge: TAGGG
# Vertex: GGCTA, coverage: 101
# -> Out edge: GCTAA
# -> Out edge: GCTAC
# -> Out edge: GCTAG
# -> Out edge: GCTAT
# -> In edge: TGGCT
# -> In edge: AGGCT
# -> In edge: GGGCT
# -> In edge: CGGCT
# Vertex: AACGT, coverage: 13
# -> Out edge: ACGTA
# -> Out edge: ACGTC
# -> Out edge: ACGTG
# -> Out edge: ACGTT
# -> In edge: TAACG
# -> In edge: AAACG
# -> In edge: GAACG
# -> In edge: CAACG
# Vertex: CTTCT, coverage: 383
# -> Out edge: TTCTG
# -> Out edge: TTCTT
# -> Out edge: TTCTC
# -> Out edge: TTCTA
# -> In edge: TCTTC
# -> In edge: CCTTC
# -> In edge: ACTTC
# -> In edge: GCTTC
# Vertex: TGCAA, coverage: 200
# -> Out edge: GCAAC
# -> Out edge: GCAAG
# -> Out edge: GCAAA
# -> Out edge: GCAAT
# -> In edge: GTGCA
# -> In edge: CTGCA
# -> In edge: TTGCA
# Vertex: GCTGG, coverage: 660
# -> Out edge: CTGGT
# -> Out edge: CTGGA
# -> Out edge: CTGGG
# -> Out edge: CTGGC
# -> In edge: AGCTG
# -> In edge: TGCTG
# -> In edge: GGCTG
# -> In edge: CGCTG
# Vertex: CTTTG, coverage: 374
# -> Out edge: TTTGA
# -> Out edge: TTTGC
# -> Out edge: TTTGT
# -> Out edge: TTTGG
# -> In edge: TCTTT
# -> In edge: CCTTT
# -> In edge: GCTTT
# -> In edge: ACTTT
# Vertex: GCACC, coverage: 10
# -> Out edge: CACCC
# -> Out edge: CACCG
# -> Out edge: CACCA
# -> In edge: AGCAC
# -> In edge: GGCAC
# -> In edge: TGCAC
# Vertex: TTCCG, coverage: 302
# -> Out edge: TCCGT
# -> Out edge: TCCGG
# -> Out edge: TCCGC
# -> Out edge: TCCGA
# -> In edge: CTTCC
# -> In edge: ATTCC
# -> In edge: GTTCC
# -> In edge: TTTCC
# Vertex: CGCCC, coverage: 103
# -> Out edge: GCCCC
# -> Out edge: GCCCA
# -> Out edge: GCCCT
# -> In edge: CCGCC
# -> In edge: ACGCC
# -> In edge: TCGCC
# -> In edge: GCGCC
# Vertex: AACTA, coverage: 103
# -> Out edge: ACTAG
# -> Out edge: ACTAC
# -> Out edge: ACTAT
# -> Out edge: ACTAA
# -> In edge: GAACT
# -> In edge: AAACT
# -> In edge: TAACT
# -> In edge: CAACT
# Vertex: ACGCT, coverage: 99
# -> Out edge: CGCTC
# -> Out edge: CGCTA
# -> Out edge: CGCTG
# -> In edge: AACGC
# -> In edge: GACGC
# -> In edge: TACGC
# -> In edge: CACGC
# Vertex: GGTTG, coverage: 382
# -> Out edge: GTTGG
# -> Out edge: GTTGT
# -> Out edge: GTTGA
# -> Out edge: GTTGC
# -> In edge: CGGTT
# -> In edge: TGGTT
# -> In edge: GGGTT
# -> In edge: AGGTT
# Vertex: GGAGT, coverage: 372
# -> Out edge: GAGTT
# -> Out edge: GAGTG
# -> Out edge: GAGTA
# -> Out edge: GAGTC
# -> In edge: GGGAG
# -> In edge: AGGAG
# -> In edge: TGGAG
# -> In edge: CGGAG
# Vertex: TCATT, coverage: 193
# -> Out edge: CATTA
# -> Out edge: CATTC
# -> Out edge: CATTT
# -> Out edge: CATTG
# -> In edge: CTCAT
# -> In edge: TTCAT
# -> In edge: ATCAT
# -> In edge: GTCAT
# Vertex: GGGTC, coverage: 375
# -> Out edge: GGTCT
# -> Out edge: GGTCA
# -> Out edge: GGTCG
# -> Out edge: GGTCC
# -> In edge: TGGGT
# -> In edge: AGGGT
# -> In edge: GGGGT
# -> In edge: CGGGT
# Vertex: TTGGC, coverage: 568
# -> Out edge: TGGCT
# -> Out edge: TGGCC
# -> Out edge: TGGCG
# -> Out edge: TGGCA
# -> In edge: CTTGG
# -> In edge: GTTGG
# -> In edge: ATTGG
# -> In edge: TTTGG
# Vertex: CCTCA, coverage: 103
# -> Out edge: CTCAT
# -> Out edge: CTCAA
# -> Out edge: CTCAC
# -> Out edge: CTCAG
# -> In edge: TCCTC
# -> In edge: GCCTC
# -> In edge: ACCTC
# -> In edge: CCCTC
# Vertex: CGTAG, coverage: 16
# -> Out edge: GTAGC
# -> Out edge: GTAGT
# -> Out edge: GTAGG
# -> Out edge: GTAGA
# -> In edge: TCGTA
# -> In edge: CCGTA
# -> In edge: GCGTA
# -> In edge: ACGTA
# Vertex: GCGAT, coverage: 265
# -> Out edge: CGATA
# -> Out edge: CGATT
# -> Out edge: CGATG
# -> Out edge: CGATC
# -> In edge: GGCGA
# -> In edge: TGCGA
# -> In edge: CGCGA
# -> In edge: AGCGA
# Vertex: CAATT, coverage: 377
# -> Out edge: AATTG
# -> Out edge: AATTA
# -> Out edge: AATTT
# -> Out edge: AATTC
# -> In edge: ACAAT
# -> In edge: CCAAT
# -> In edge: TCAAT
# -> In edge: GCAAT
# Vertex: CTGGC, coverage: 437
# -> Out edge: TGGCT
# -> Out edge: TGGCC
# -> Out edge: TGGCG
# -> Out edge: TGGCA
# -> In edge: TCTGG
# -> In edge: GCTGG
# -> In edge: CCTGG
# -> In edge: ACTGG
# Vertex: CCTAG, coverage: 383
# -> Out edge: CTAGC
# -> Out edge: CTAGG
# -> Out edge: CTAGA
# -> Out edge: CTAGT
# -> In edge: CCCTA
# -> In edge: ACCTA
# -> In edge: GCCTA
# -> In edge: TCCTA
# Vertex: CAACC, coverage: 19
# -> Out edge: AACCC
# -> Out edge: AACCA
# -> Out edge: AACCG
# -> Out edge: AACCT
# -> In edge: GCAAC
# -> In edge: ACAAC
# -> In edge: CCAAC
# Vertex: AGTAG, coverage: 566
# -> Out edge: GTAGC
# -> Out edge: GTAGT
# -> Out edge: GTAGG
# -> Out edge: GTAGA
# -> In edge: GAGTA
# -> In edge: AAGTA
# -> In edge: TAGTA
# -> In edge: CAGTA
# Vertex: GGTCA, coverage: 16
# -> Out edge: GTCAG
# -> Out edge: GTCAA
# -> Out edge: GTCAT
# -> Out edge: GTCAC
# -> In edge: CGGTC
# -> In edge: AGGTC
# -> In edge: TGGTC
# -> In edge: GGGTC
# Vertex: TACCT, coverage: 198
# -> Out edge: ACCTA
# -> Out edge: ACCTT
# -> Out edge: ACCTG
# -> In edge: CTACC
# -> In edge: ATACC
# -> In edge: GTACC
# -> In edge: TTACC
# Vertex: GCACT, coverage: 95
# -> Out edge: CACTG
# -> Out edge: CACTC
# -> Out edge: CACTT
# -> Out edge: CACTA
# -> In edge: AGCAC
# -> In edge: CGCAC
# -> In edge: GGCAC
# -> In edge: TGCAC
# Vertex: CAATG, coverage: 384
# -> Out edge: AATGA
# -> Out edge: AATGC
# -> Out edge: AATGG
# -> Out edge: AATGT
# -> In edge: ACAAT
# -> In edge: CCAAT
# -> In edge: TCAAT
# -> In edge: GCAAT
# Vertex: CCATC, coverage: 105
# -> Out edge: CATCC
# -> Out edge: CATCA
# -> Out edge: CATCT
# -> Out edge: CATCG
# -> In edge: ACCAT
# -> In edge: TCCAT
# -> In edge: GCCAT
# -> In edge: CCCAT
# Vertex: TCGTG, coverage: 7
# -> Out edge: CGTGT
# -> Out edge: CGTGC
# -> Out edge: CGTGG
# -> In edge: ATCGT
# -> In edge: GTCGT
# -> In edge: CTCGT
# -> In edge: TTCGT
# Vertex: AGTCT, coverage: 381
# -> Out edge: GTCTC
# -> Out edge: GTCTA
# -> Out edge: GTCTG
# -> Out edge: GTCTT
# -> In edge: TAGTC
# -> In edge: CAGTC
# -> In edge: GAGTC
# -> In edge: AAGTC
# Vertex: TATTA, coverage: 195
# -> Out edge: ATTAC
# -> Out edge: ATTAT
# -> Out edge: ATTAG
# -> Out edge: ATTAA
# -> In edge: TTATT
# -> In edge: CTATT
# -> In edge: GTATT
# -> In edge: ATATT
# Vertex: GGAGA, coverage: 425
# -> Out edge: GAGAA
# -> Out edge: GAGAT
# -> Out edge: GAGAC
# -> Out edge: GAGAG
# -> In edge: GGGAG
# -> In edge: AGGAG
# -> In edge: TGGAG
# -> In edge: CGGAG
# Vertex: AAGCG, coverage: 284
# -> Out edge: AGCGA
# -> Out edge: AGCGG
# -> Out edge: AGCGT
# -> Out edge: AGCGC
# -> In edge: AAAGC
# -> In edge: CAAGC
# -> In edge: TAAGC
# -> In edge: GAAGC
# Vertex: CACGA, coverage: 202
# -> Out edge: ACGAC
# -> Out edge: ACGAA
# -> Out edge: ACGAT
# -> Out edge: ACGAG
# -> In edge: TCACG
# -> In edge: CCACG
# -> In edge: GCACG
# -> In edge: ACACG
# Vertex: TCCAA, coverage: 927
# -> Out edge: CCAAA
# -> Out edge: CCAAT
# -> Out edge: CCAAG
# -> Out edge: CCAAC
# -> In edge: CTCCA
# -> In edge: TTCCA
# -> In edge: GTCCA
# -> In edge: ATCCA
# Vertex: CCACA, coverage: 656
# -> Out edge: CACAT
# -> Out edge: CACAA
# -> Out edge: CACAG
# -> Out edge: CACAC
# -> In edge: TCCAC
# -> In edge: ACCAC
# -> In edge: GCCAC
# -> In edge: CCCAC
# Vertex: TGGGC, coverage: 286
# -> Out edge: GGGCC
# -> Out edge: GGGCT
# -> Out edge: GGGCA
# -> Out edge: GGGCG
# -> In edge: ATGGG
# -> In edge: GTGGG
# -> In edge: TTGGG
# Vertex: TTCCA, coverage: 561
# -> Out edge: TCCAC
# -> Out edge: TCCAA
# -> Out edge: TCCAT
# -> Out edge: TCCAG
# -> In edge: CTTCC
# -> In edge: ATTCC
# -> In edge: GTTCC
# -> In edge: TTTCC
# Vertex: ATCAG, coverage: 103
# -> Out edge: TCAGG
# -> Out edge: TCAGT
# -> Out edge: TCAGA
# -> Out edge: TCAGC
# -> In edge: CATCA
# -> In edge: AATCA
# -> In edge: TATCA
# -> In edge: GATCA
# Vertex: TCTTG, coverage: 406
# -> Out edge: CTTGG
# -> Out edge: CTTGT
# -> Out edge: CTTGA
# -> Out edge: CTTGC
# -> In edge: CTCTT
# -> In edge: TTCTT
# -> In edge: ATCTT
# -> In edge: GTCTT
# Vertex: CGGGG, coverage: 234
# -> Out edge: GGGGG
# -> Out edge: GGGGC
# -> Out edge: GGGGT
# -> Out edge: GGGGA
# -> In edge: CCGGG
# -> In edge: GCGGG
# -> In edge: ACGGG
# -> In edge: TCGGG
# Vertex: GGCTC, coverage: 97
# -> Out edge: GCTCC
# -> Out edge: GCTCG
# -> Out edge: GCTCA
# -> Out edge: GCTCT
# -> In edge: TGGCT
# -> In edge: AGGCT
# -> In edge: GGGCT
# Vertex: TCGCC, coverage: 9
# -> Out edge: CGCCC
# -> Out edge: CGCCT
# -> Out edge: CGCCG
# -> Out edge: CGCCA
# -> In edge: TTCGC
# -> In edge: GTCGC
# -> In edge: CTCGC
# Vertex: TCGTT, coverage: 191
# -> Out edge: CGTTG
# -> Out edge: CGTTA
# -> Out edge: CGTTT
# -> Out edge: CGTTC
# -> In edge: ATCGT
# -> In edge: GTCGT
# -> In edge: TTCGT
# Vertex: CCCCA, coverage: 933
# -> Out edge: CCCAA
# -> Out edge: CCCAG
# -> Out edge: CCCAT
# -> Out edge: CCCAC
# -> In edge: GCCCC
# -> In edge: TCCCC
# -> In edge: ACCCC
# -> In edge: CCCCC
# Vertex: CTACA, coverage: 197
# -> Out edge: TACAA
# -> Out edge: TACAC
# -> Out edge: TACAG
# -> Out edge: TACAT
# -> In edge: TCTAC
# -> In edge: ACTAC
# -> In edge: CCTAC
# -> In edge: GCTAC
# Vertex: GTACT, coverage: 97
# -> Out edge: TACTA
# -> Out edge: TACTG
# -> Out edge: TACTC
# -> Out edge: TACTT
# -> In edge: TGTAC
# -> In edge: CGTAC
# -> In edge: AGTAC
# -> In edge: GGTAC
# Vertex: GCGGG, coverage: 152
# -> Out edge: CGGGA
# -> Out edge: CGGGC
# -> Out edge: CGGGT
# -> Out edge: CGGGG
# -> In edge: TGCGG
# -> In edge: AGCGG
# -> In edge: GGCGG
# -> In edge: CGCGG
# Vertex: TTGAC, coverage: 377
# -> Out edge: TGACT
# -> Out edge: TGACA
# -> Out edge: TGACG
# -> Out edge: TGACC
# -> In edge: TTTGA
# -> In edge: GTTGA
# -> In edge: ATTGA
# -> In edge: CTTGA
# Vertex: AAGTG, coverage: 390
# -> Out edge: AGTGC
# -> Out edge: AGTGT
# -> Out edge: AGTGG
# -> Out edge: AGTGA
# -> In edge: AAAGT
# -> In edge: CAAGT
# -> In edge: TAAGT
# -> In edge: GAAGT
# Vertex: CTTGA, coverage: 295
# -> Out edge: TTGAG
# -> Out edge: TTGAA
# -> Out edge: TTGAT
# -> Out edge: TTGAC
# -> In edge: CCTTG
# -> In edge: ACTTG
# -> In edge: GCTTG
# -> In edge: TCTTG
# Vertex: CGGCC, coverage: 18
# -> Out edge: GGCCT
# -> Out edge: GGCCC
# -> Out edge: GGCCG
# -> Out edge: GGCCA
# -> In edge: CCGGC
# -> In edge: GCGGC
# -> In edge: ACGGC
# -> In edge: TCGGC
# Vertex: GTGAA, coverage: 566
# -> Out edge: TGAAT
# -> Out edge: TGAAG
# -> Out edge: TGAAA
# -> Out edge: TGAAC
# -> In edge: CGTGA
# -> In edge: GGTGA
# -> In edge: TGTGA
# -> In edge: AGTGA
# Vertex: CTAGT, coverage: 281
# -> Out edge: TAGTC
# -> Out edge: TAGTA
# -> Out edge: TAGTG
# -> Out edge: TAGTT
# -> In edge: ACTAG
# -> In edge: GCTAG
# -> In edge: CCTAG
# -> In edge: TCTAG
# Vertex: ACTCC, coverage: 379
# -> Out edge: CTCCC
# -> Out edge: CTCCA
# -> Out edge: CTCCT
# -> Out edge: CTCCG
# -> In edge: GACTC
# -> In edge: CACTC
# -> In edge: TACTC
# -> In edge: AACTC
# Vertex: TTCGG, coverage: 9
# -> Out edge: TCGGT
# -> Out edge: TCGGG
# -> Out edge: TCGGC
# -> In edge: TTTCG
# -> In edge: ATTCG
# -> In edge: GTTCG
# Vertex: CTCCT, coverage: 374
# -> Out edge: TCCTC
# -> Out edge: TCCTT
# -> Out edge: TCCTG
# -> Out edge: TCCTA
# -> In edge: GCTCC
# -> In edge: ACTCC
# -> In edge: TCTCC
# -> In edge: CCTCC
# Vertex: CGGTG, coverage: 283
# -> Out edge: GGTGG
# -> Out edge: GGTGT
# -> Out edge: GGTGC
# -> Out edge: GGTGA
# -> In edge: ACGGT
# -> In edge: GCGGT
# -> In edge: CCGGT
# -> In edge: TCGGT
# Vertex: ACGGG, coverage: 464
# -> Out edge: CGGGA
# -> Out edge: CGGGC
# -> Out edge: CGGGT
# -> Out edge: CGGGG
# -> In edge: GACGG
# -> In edge: TACGG
# -> In edge: CACGG
# -> In edge: AACGG
# Vertex: GATTC, coverage: 376
# -> Out edge: ATTCT
# -> Out edge: ATTCG
# -> Out edge: ATTCC
# -> Out edge: ATTCA
# -> In edge: CGATT
# -> In edge: GGATT
# -> In edge: AGATT
# -> In edge: TGATT
# Vertex: CACAG, coverage: 571
# -> Out edge: ACAGG
# -> Out edge: ACAGC
# -> Out edge: ACAGA
# -> Out edge: ACAGT
# -> In edge: TCACA
# -> In edge: CCACA
# -> In edge: ACACA
# -> In edge: GCACA
# Vertex: TTAAA, coverage: 283
# -> Out edge: TAAAG
# -> Out edge: TAAAA
# -> Out edge: TAAAT
# -> Out edge: TAAAC
# -> In edge: CTTAA
# -> In edge: GTTAA
# -> In edge: TTTAA
# -> In edge: ATTAA
# Vertex: CAAAC, coverage: 483
# -> Out edge: AAACG
# -> Out edge: AAACA
# -> Out edge: AAACT
# -> Out edge: AAACC
# -> In edge: ACAAA
# -> In edge: TCAAA
# -> In edge: GCAAA
# -> In edge: CCAAA
# Vertex: CCTGG, coverage: 286
# -> Out edge: CTGGC
# -> Out edge: CTGGA
# -> Out edge: CTGGG
# -> Out edge: CTGGT
# -> In edge: TCCTG
# -> In edge: ACCTG
# -> In edge: CCCTG
# -> In edge: GCCTG
# Vertex: ATGGA, coverage: 201
# -> Out edge: TGGAT
# -> Out edge: TGGAA
# -> Out edge: TGGAG
# -> In edge: TATGG
# -> In edge: GATGG
# -> In edge: AATGG
# -> In edge: CATGG
# Vertex: ATACT, coverage: 288
# -> Out edge: TACTA
# -> Out edge: TACTG
# -> Out edge: TACTC
# -> Out edge: TACTT
# -> In edge: AATAC
# -> In edge: CATAC
# -> In edge: GATAC
# -> In edge: TATAC
# Vertex: GGCTT, coverage: 195
# -> Out edge: GCTTA
# -> Out edge: GCTTT
# -> Out edge: GCTTG
# -> Out edge: GCTTC
# -> In edge: TGGCT
# -> In edge: AGGCT
# -> In edge: GGGCT
# -> In edge: CGGCT
# Vertex: AACCT, coverage: 293
# -> Out edge: ACCTA
# -> Out edge: ACCTT
# -> Out edge: ACCTC
# -> Out edge: ACCTG
# -> In edge: TAACC
# -> In edge: GAACC
# -> In edge: CAACC
# -> In edge: AAACC
# Vertex: CCGAT, coverage: 188
# -> Out edge: CGATA
# -> Out edge: CGATT
# -> Out edge: CGATG
# -> Out edge: CGATC
# -> In edge: TCCGA
# -> In edge: GCCGA
# -> In edge: CCCGA
# Vertex: GATAT, coverage: 15
# -> Out edge: ATATA
# -> Out edge: ATATC
# -> Out edge: ATATG
# -> Out edge: ATATT
# -> In edge: CGATA
# -> In edge: TGATA
# -> In edge: AGATA
# -> In edge: GGATA
# Vertex: CACCT, coverage: 106
# -> Out edge: ACCTA
# -> Out edge: ACCTT
# -> Out edge: ACCTC
# -> Out edge: ACCTG
# -> In edge: ACACC
# -> In edge: CCACC
# Vertex: GCGAA, coverage: 295
# -> Out edge: CGAAC
# -> Out edge: CGAAG
# -> Out edge: CGAAA
# -> Out edge: CGAAT
# -> In edge: AGCGA
# -> In edge: TGCGA
# -> In edge: CGCGA
# -> In edge: GGCGA
# Vertex: TTAGA, coverage: 284
# -> Out edge: TAGAA
# -> Out edge: TAGAG
# -> Out edge: TAGAT
# -> Out edge: TAGAC
# -> In edge: GTTAG
# -> In edge: ATTAG
# -> In edge: CTTAG
# -> In edge: TTTAG
# Vertex: GGACG, coverage: 285
# -> Out edge: GACGG
# -> Out edge: GACGA
# -> Out edge: GACGC
# -> Out edge: GACGT
# -> In edge: AGGAC
# -> In edge: CGGAC
# -> In edge: TGGAC
# -> In edge: GGGAC
# Vertex: CCTGA, coverage: 606
# -> Out edge: CTGAG
# -> Out edge: CTGAC
# -> Out edge: CTGAA
# -> Out edge: CTGAT
# -> In edge: TCCTG
# -> In edge: ACCTG
# -> In edge: CCCTG
# -> In edge: GCCTG
# Vertex: CGCAA, coverage: 16
# -> Out edge: GCAAC
# -> Out edge: GCAAG
# -> Out edge: GCAAA
# -> Out edge: GCAAT
# -> In edge: GCGCA
# -> In edge: ACGCA
# -> In edge: TCGCA
# -> In edge: CCGCA
# Vertex: TAATC, coverage: 194
# -> Out edge: AATCT
# -> Out edge: AATCG
# -> Out edge: AATCC
# -> Out edge: AATCA
# -> In edge: GTAAT
# -> In edge: ATAAT
# -> In edge: CTAAT
# -> In edge: TTAAT
# Vertex: CGAAC, coverage: 111
# -> Out edge: GAACT
# -> Out edge: GAACG
# -> Out edge: GAACC
# -> Out edge: GAACA
# -> In edge: CCGAA
# -> In edge: GCGAA
# -> In edge: TCGAA
# -> In edge: ACGAA
# Vertex: CTCGT, coverage: 192
# -> Out edge: TCGTA
# -> Out edge: TCGTG
# -> Out edge: TCGTC
# -> In edge: TCTCG
# -> In edge: ACTCG
# -> In edge: CCTCG
# -> In edge: GCTCG
# Vertex: GCGAC, coverage: 274
# -> Out edge: CGACT
# -> Out edge: CGACA
# -> Out edge: CGACC
# -> Out edge: CGACG
# -> In edge: AGCGA
# -> In edge: TGCGA
# -> In edge: CGCGA
# -> In edge: GGCGA
# Vertex: GGGAT, coverage: 415
# -> Out edge: GGATG
# -> Out edge: GGATC
# -> Out edge: GGATT
# -> Out edge: GGATA
# -> In edge: CGGGA
# -> In edge: TGGGA
# -> In edge: AGGGA
# -> In edge: GGGGA
# Vertex: GGTTC, coverage: 287
# -> Out edge: GTTCT
# -> Out edge: GTTCG
# -> Out edge: GTTCC
# -> Out edge: GTTCA
# -> In edge: CGGTT
# -> In edge: TGGTT
# -> In edge: GGGTT
# -> In edge: AGGTT
# Vertex: CAGTT, coverage: 107
# -> Out edge: AGTTT
# -> Out edge: AGTTG
# -> Out edge: AGTTC
# -> In edge: GCAGT
# -> In edge: ACAGT
# -> In edge: TCAGT
# -> In edge: CCAGT
# Vertex: TCGAT, coverage: 106
# -> Out edge: CGATA
# -> Out edge: CGATT
# -> Out edge: CGATG
# -> Out edge: CGATC
# -> In edge: CTCGA
# -> In edge: GTCGA
# -> In edge: ATCGA
# -> In edge: TTCGA
# Vertex: AAACG, coverage: 472
# -> Out edge: AACGT
# -> Out edge: AACGC
# -> Out edge: AACGG
# -> Out edge: AACGA
# -> In edge: CAAAC
# -> In edge: AAAAC
# -> In edge: GAAAC
# -> In edge: TAAAC
# Vertex: TTTAG, coverage: 194
# -> Out edge: TTAGG
# -> Out edge: TTAGA
# -> Out edge: TTAGC
# -> Out edge: TTAGT
# -> In edge: TTTTA
# -> In edge: ATTTA
# -> In edge: GTTTA
# -> In edge: CTTTA
# Vertex: ACTAC, coverage: 93
# -> Out edge: CTACA
# -> Out edge: CTACG
# -> Out edge: CTACT
# -> In edge: TACTA
# -> In edge: GACTA
# -> In edge: CACTA
# -> In edge: AACTA
# Vertex: TACTT, coverage: 102
# -> Out edge: ACTTC
# -> Out edge: ACTTG
# -> Out edge: ACTTT
# -> Out edge: ACTTA
# -> In edge: TTACT
# -> In edge: GTACT
# -> In edge: CTACT
# -> In edge: ATACT
# Vertex: CAGCT, coverage: 188
# -> Out edge: AGCTT
# -> Out edge: AGCTC
# -> Out edge: AGCTG
# -> Out edge: AGCTA
# -> In edge: TCAGC
# -> In edge: ACAGC
# -> In edge: CCAGC
# -> In edge: GCAGC
# Vertex: AGGGC, coverage: 106
# -> Out edge: GGGCC
# -> Out edge: GGGCT
# -> Out edge: GGGCA
# -> Out edge: GGGCG
# -> In edge: GAGGG
# -> In edge: AAGGG
# -> In edge: CAGGG
# -> In edge: TAGGG
# Vertex: AAGTA, coverage: 197
# -> Out edge: AGTAA
# -> Out edge: AGTAC
# -> Out edge: AGTAT
# -> Out edge: AGTAG
# -> In edge: AAAGT
# -> In edge: CAAGT
# -> In edge: TAAGT
# -> In edge: GAAGT
# Vertex: ACAAC, coverage: 194
# -> Out edge: CAACA
# -> Out edge: CAACC
# -> Out edge: CAACG
# -> In edge: GACAA
# -> In edge: AACAA
# -> In edge: CACAA
# -> In edge: TACAA
# Vertex: TTGAG, coverage: 569
# -> Out edge: TGAGG
# -> Out edge: TGAGC
# -> Out edge: TGAGT
# -> Out edge: TGAGA
# -> In edge: TTTGA
# -> In edge: GTTGA
# -> In edge: ATTGA
# -> In edge: CTTGA
# Vertex: TTGCG, coverage: 284
# -> Out edge: TGCGG
# -> Out edge: TGCGA
# -> Out edge: TGCGC
# -> Out edge: TGCGT
# -> In edge: TTTGC
# -> In edge: ATTGC
# -> In edge: CTTGC
# -> In edge: GTTGC
# Vertex: TTTCT, coverage: 404
# -> Out edge: TTCTG
# -> Out edge: TTCTT
# -> Out edge: TTCTC
# -> Out edge: TTCTA
# -> In edge: GTTTC
# -> In edge: CTTTC
# -> In edge: ATTTC
# -> In edge: TTTTC
# Vertex: AAAAA, coverage: 401
# -> Out edge: AAAAT
# -> Out edge: AAAAG
# -> Out edge: AAAAC
# -> Out edge: AAAAA
# -> In edge: GAAAA
# -> In edge: TAAAA
# -> In edge: CAAAA
# -> In edge: AAAAA
# Vertex: AGTGG, coverage: 292
# -> Out edge: GTGGA
# -> Out edge: GTGGT
# -> Out edge: GTGGC
# -> Out edge: GTGGG
# -> In edge: GAGTG
# -> In edge: TAGTG
# -> In edge: AAGTG
# -> In edge: CAGTG
# Vertex: CGCAG, coverage: 659
# -> Out edge: GCAGA
# -> Out edge: GCAGT
# -> Out edge: GCAGC
# -> Out edge: GCAGG
# -> In edge: GCGCA
# -> In edge: ACGCA
# -> In edge: TCGCA
# -> In edge: CCGCA
# Vertex: ATAAG, coverage: 387
# -> Out edge: TAAGG
# -> Out edge: TAAGT
# -> Out edge: TAAGC
# -> Out edge: TAAGA
# -> In edge: TATAA
# -> In edge: GATAA
# -> In edge: CATAA
# -> In edge: AATAA
# Vertex: TGCGC, coverage: 294
# -> Out edge: GCGCA
# -> Out edge: GCGCT
# -> Out edge: GCGCG
# -> Out edge: GCGCC
# -> In edge: GTGCG
# -> In edge: TTGCG
# -> In edge: ATGCG
# -> In edge: CTGCG
# Vertex: GTTAA, coverage: 109
# -> Out edge: TTAAG
# -> Out edge: TTAAA
# -> Out edge: TTAAC
# -> Out edge: TTAAT
# -> In edge: TGTTA
# -> In edge: CGTTA
# -> In edge: GGTTA
# Vertex: CCAGC, coverage: 521
# -> Out edge: CAGCT
# -> Out edge: CAGCC
# -> Out edge: CAGCA
# -> Out edge: CAGCG
# -> In edge: ACCAG
# -> In edge: GCCAG
# -> In edge: CCCAG
# -> In edge: TCCAG
# Vertex: TGTGA, coverage: 382
# -> Out edge: GTGAT
# -> Out edge: GTGAC
# -> Out edge: GTGAG
# -> Out edge: GTGAA
# -> In edge: CTGTG
# -> In edge: TTGTG
# -> In edge: GTGTG
# -> In edge: ATGTG
# Vertex: TACAC, coverage: 102
# -> Out edge: ACACC
# -> Out edge: ACACT
# -> Out edge: ACACA
# -> Out edge: ACACG
# -> In edge: TTACA
# -> In edge: CTACA
# -> In edge: ATACA
# -> In edge: GTACA
# Vertex: ACCCT, coverage: 101
# -> Out edge: CCCTA
# -> Out edge: CCCTT
# -> Out edge: CCCTG
# -> In edge: CACCC
# -> In edge: AACCC
# -> In edge: GACCC
# -> In edge: TACCC
# Vertex: TTAAT, coverage: 205
# -> Out edge: TAATG
# -> Out edge: TAATT
# -> Out edge: TAATA
# -> Out edge: TAATC
# -> In edge: CTTAA
# -> In edge: GTTAA
# -> In edge: TTTAA
# -> In edge: ATTAA
# Vertex: GTTTC, coverage: 224
# -> Out edge: TTTCG
# -> Out edge: TTTCA
# -> Out edge: TTTCT
# -> Out edge: TTTCC
# -> In edge: CGTTT
# -> In edge: AGTTT
# -> In edge: GGTTT
# -> In edge: TGTTT
# Vertex: ACCTG, coverage: 372
# -> Out edge: CCTGT
# -> Out edge: CCTGG
# -> Out edge: CCTGC
# -> Out edge: CCTGA
# -> In edge: GACCT
# -> In edge: TACCT
# -> In edge: AACCT
# -> In edge: CACCT
# Vertex: TAAGC, coverage: 101
# -> Out edge: AAGCG
# -> Out edge: AAGCC
# -> Out edge: AAGCT
# -> Out edge: AAGCA
# -> In edge: TTAAG
# -> In edge: ATAAG
# -> In edge: GTAAG
# -> In edge: CTAAG
# Vertex: CCTGC, coverage: 291
# -> Out edge: CTGCC
# -> Out edge: CTGCA
# -> Out edge: CTGCT
# -> Out edge: CTGCG
# -> In edge: TCCTG
# -> In edge: ACCTG
# -> In edge: CCCTG
# -> In edge: GCCTG
# Vertex: CCGTG, coverage: 288
# -> Out edge: CGTGA
# -> Out edge: CGTGT
# -> Out edge: CGTGC
# -> Out edge: CGTGG
# -> In edge: TCCGT
# -> In edge: ACCGT
# -> In edge: GCCGT
# -> In edge: CCCGT
# Vertex: AGAGC, coverage: 112
# -> Out edge: GAGCA
# -> Out edge: GAGCT
# -> Out edge: GAGCG
# -> Out edge: GAGCC
# -> In edge: AAGAG
# -> In edge: TAGAG
# -> In edge: CAGAG
# -> In edge: GAGAG
# Vertex: ACCGC, coverage: 6
# -> Out edge: CCGCG
# -> Out edge: CCGCT
# -> Out edge: CCGCC
# -> In edge: CACCG
# -> In edge: AACCG
# -> In edge: GACCG
# Vertex: AACGC, coverage: 193
# -> Out edge: ACGCC
# -> Out edge: ACGCT
# -> Out edge: ACGCA
# -> Out edge: ACGCG
# -> In edge: AAACG
# -> In edge: GAACG
# -> In edge: CAACG
# Vertex: GCTCC, coverage: 457
# -> Out edge: CTCCC
# -> Out edge: CTCCA
# -> Out edge: CTCCT
# -> Out edge: CTCCG
# -> In edge: CGCTC
# -> In edge: AGCTC
# -> In edge: GGCTC
# -> In edge: TGCTC
# Vertex: CGTCT, coverage: 283
# -> Out edge: GTCTC
# -> Out edge: GTCTT
# -> Out edge: GTCTG
# -> Out edge: GTCTA
# -> In edge: ACGTC
# -> In edge: TCGTC
# -> In edge: GCGTC
# -> In edge: CCGTC
# Vertex: CAGTC, coverage: 286
# -> Out edge: AGTCT
# -> Out edge: AGTCA
# -> Out edge: AGTCG
# -> Out edge: AGTCC
# -> In edge: GCAGT
# -> In edge: ACAGT
# -> In edge: TCAGT
# -> In edge: CCAGT
# Vertex: GACCA, coverage: 193
# -> Out edge: ACCAG
# -> Out edge: ACCAC
# -> Out edge: ACCAT
# -> Out edge: ACCAA
# -> In edge: TGACC
# -> In edge: GGACC
# -> In edge: AGACC
# Vertex: CAACT, coverage: 190
# -> Out edge: AACTG
# -> Out edge: AACTT
# -> Out edge: AACTC
# -> Out edge: AACTA
# -> In edge: GCAAC
# -> In edge: TCAAC
# -> In edge: CCAAC
# Vertex: TCGCA, coverage: 9
# -> Out edge: CGCAA
# -> Out edge: CGCAT
# -> Out edge: CGCAC
# -> Out edge: CGCAG
# -> In edge: TTCGC
# -> In edge: GTCGC
# -> In edge: ATCGC
# -> In edge: CTCGC
# Vertex: ACTTA, coverage: 4
# -> Out edge: CTTAA
# -> Out edge: CTTAG
# -> In edge: TACTT
# -> In edge: CACTT
# -> In edge: GACTT
# Vertex: TGGCG, coverage: 256
# -> Out edge: GGCGA
# -> Out edge: GGCGG
# -> Out edge: GGCGC
# -> Out edge: GGCGT
# -> In edge: CTGGC
# -> In edge: GTGGC
# -> In edge: TTGGC
# -> In edge: ATGGC
# Vertex: TCTCT, coverage: 470
# -> Out edge: CTCTG
# -> Out edge: CTCTT
# -> Out edge: CTCTA
# -> Out edge: CTCTC
# -> In edge: ATCTC
# -> In edge: GTCTC
# -> In edge: CTCTC
# -> In edge: TTCTC
# Vertex: TCCTC, coverage: 381
# -> Out edge: CCTCT
# -> Out edge: CCTCG
# -> Out edge: CCTCA
# -> Out edge: CCTCC
# -> In edge: ATCCT
# -> In edge: GTCCT
# -> In edge: CTCCT
# -> In edge: TTCCT
# Vertex: GTATC, coverage: 97
# -> Out edge: TATCA
# -> Out edge: TATCT
# -> Out edge: TATCC
# -> In edge: CGTAT
# -> In edge: GGTAT
# -> In edge: AGTAT
# Vertex: TTCTT, coverage: 659
# -> Out edge: TCTTT
# -> Out edge: TCTTC
# -> Out edge: TCTTG
# -> Out edge: TCTTA
# -> In edge: ATTCT
# -> In edge: CTTCT
# -> In edge: GTTCT
# -> In edge: TTTCT
# Vertex: ACAAA, coverage: 837
# -> Out edge: CAAAC
# -> Out edge: CAAAA
# -> Out edge: CAAAT
# -> Out edge: CAAAG
# -> In edge: TACAA
# -> In edge: AACAA
# -> In edge: CACAA
# -> In edge: GACAA
# Vertex: TTATC, coverage: 191
# -> Out edge: TATCC
# -> Out edge: TATCG
# -> Out edge: TATCA
# -> Out edge: TATCT
# -> In edge: ATTAT
# -> In edge: TTTAT
# -> In edge: CTTAT
# -> In edge: GTTAT
# Vertex: TGCAG, coverage: 310
# -> Out edge: GCAGA
# -> Out edge: GCAGT
# -> Out edge: GCAGC
# -> Out edge: GCAGG
# -> In edge: GTGCA
# -> In edge: CTGCA
# -> In edge: ATGCA
# -> In edge: TTGCA
# Vertex: TACCA, coverage: 104
# -> Out edge: ACCAG
# -> Out edge: ACCAC
# -> Out edge: ACCAT
# -> Out edge: ACCAA
# -> In edge: CTACC
# -> In edge: ATACC
# -> In edge: GTACC
# -> In edge: TTACC
# Vertex: GAAAC, coverage: 379
# -> Out edge: AAACG
# -> Out edge: AAACA
# -> Out edge: AAACT
# -> Out edge: AAACC
# -> In edge: CGAAA
# -> In edge: AGAAA
# -> In edge: TGAAA
# -> In edge: GGAAA
# Vertex: CTAGC, coverage: 102
# -> Out edge: TAGCA
# -> Out edge: TAGCC
# -> Out edge: TAGCT
# -> Out edge: TAGCG
# -> In edge: ACTAG
# -> In edge: CCTAG
# -> In edge: GCTAG
# -> In edge: TCTAG
# Vertex: CATTC, coverage: 103
# -> Out edge: ATTCT
# -> Out edge: ATTCG
# -> Out edge: ATTCC
# -> Out edge: ATTCA
# -> In edge: GCATT
# -> In edge: ACATT
# -> In edge: TCATT
# -> In edge: CCATT
# Vertex: GACTA, coverage: 97
# -> Out edge: ACTAG
# -> Out edge: ACTAC
# -> Out edge: ACTAT
# -> Out edge: ACTAA
# -> In edge: TGACT
# -> In edge: GGACT
# -> In edge: AGACT
# Vertex: GAAAT, coverage: 163
# -> Out edge: AAATA
# -> Out edge: AAATG
# -> Out edge: AAATT
# -> Out edge: AAATC
# -> In edge: CGAAA
# -> In edge: AGAAA
# -> In edge: GGAAA
# -> In edge: TGAAA
# Vertex: TCATC, coverage: 95
# -> Out edge: CATCC
# -> Out edge: CATCG
# -> In edge: ATCAT
# -> In edge: TTCAT
# -> In edge: CTCAT
# -> In edge: GTCAT
# Vertex: TTCAC, coverage: 188
# -> Out edge: TCACA
# -> Out edge: TCACG
# -> Out edge: TCACT
# -> Out edge: TCACC
# -> In edge: TTTCA
# -> In edge: CTTCA
# -> In edge: GTTCA
# -> In edge: ATTCA
# Vertex: TAACG, coverage: 9
# -> Out edge: AACGT
# -> Out edge: AACGG
# -> Out edge: AACGA
# -> In edge: GTAAC
# -> In edge: ATAAC
# -> In edge: TTAAC
# -> In edge: CTAAC
# Vertex: CGCAT, coverage: 102
# -> Out edge: GCATT
# -> Out edge: GCATG
# -> Out edge: GCATA
# -> Out edge: GCATC
# -> In edge: GCGCA
# -> In edge: ACGCA
# -> In edge: TCGCA
# -> In edge: CCGCA
# Vertex: GGACA, coverage: 475
# -> Out edge: GACAA
# -> Out edge: GACAT
# -> Out edge: GACAG
# -> Out edge: GACAC
# -> In edge: AGGAC
# -> In edge: CGGAC
# -> In edge: GGGAC
# -> In edge: TGGAC
# Vertex: GTCAC, coverage: 7
# -> Out edge: TCACA
# -> Out edge: TCACG
# -> Out edge: TCACC
# -> In edge: TGTCA
# -> In edge: AGTCA
# -> In edge: GGTCA
# Vertex: AAGCA, coverage: 19
# -> Out edge: AGCAG
# -> Out edge: AGCAC
# -> Out edge: AGCAT
# -> Out edge: AGCAA
# -> In edge: AAAGC
# -> In edge: CAAGC
# -> In edge: TAAGC
# -> In edge: GAAGC
# Vertex: CACTT, coverage: 102
# -> Out edge: ACTTC
# -> Out edge: ACTTG
# -> Out edge: ACTTT
# -> Out edge: ACTTA
# -> In edge: GCACT
# -> In edge: ACACT
# -> In edge: CCACT
# -> In edge: TCACT
# Vertex: GCACG, coverage: 7
# -> Out edge: CACGT
# -> Out edge: CACGA
# -> Out edge: CACGG
# -> Out edge: CACGC
# -> In edge: AGCAC
# -> In edge: CGCAC
# -> In edge: GGCAC
# -> In edge: TGCAC
# Vertex: ATAAC, coverage: 657
# -> Out edge: TAACC
# -> Out edge: TAACG
# -> Out edge: TAACT
# -> Out edge: TAACA
# -> In edge: TATAA
# -> In edge: GATAA
# -> In edge: CATAA
# -> In edge: AATAA
# Vertex: TAGCT, coverage: 187
# -> Out edge: AGCTT
# -> Out edge: AGCTC
# -> Out edge: AGCTG
# -> Out edge: AGCTA
# -> In edge: CTAGC
# -> In edge: TTAGC
# -> In edge: ATAGC
# -> In edge: GTAGC
# Vertex: GTTTT, coverage: 282
# -> Out edge: TTTTA
# -> Out edge: TTTTC
# -> Out edge: TTTTG
# -> Out edge: TTTTT
# -> In edge: CGTTT
# -> In edge: AGTTT
# -> In edge: GGTTT
# -> In edge: TGTTT
# Vertex: TCATG, coverage: 94
# -> Out edge: CATGT
# -> Out edge: CATGA
# -> Out edge: CATGC
# -> Out edge: CATGG
# -> In edge: ATCAT
# -> In edge: TTCAT
# -> In edge: GTCAT
# Vertex: GCAAA, coverage: 576
# -> Out edge: CAAAC
# -> Out edge: CAAAA
# -> Out edge: CAAAT
# -> Out edge: CAAAG
# -> In edge: TGCAA
# -> In edge: CGCAA
# -> In edge: GGCAA
# -> In edge: AGCAA
# Vertex: TGATT, coverage: 383
# ...
# -> In edge: TGGTG
# -> In edge: AGGTG
# Vertex: TGTGG, coverage: 105
# -> Out edge: GTGGA
# -> Out edge: GTGGT
# -> Out edge: GTGGC
# -> Out edge: GTGGG
# -> In edge: CTGTG
# -> In edge: TTGTG
# -> In edge: GTGTG
# -> In edge: ATGTG
# Vertex: ACCAC, coverage: 473
# -> Out edge: CCACA
# -> Out edge: CCACG
# -> Out edge: CCACT
# -> Out edge: CCACC
# -> In edge: TACCA
# -> In edge: AACCA
# -> In edge: GACCA
# -> In edge: CACCA
# Vertex: AATGG, coverage: 198
# -> Out edge: ATGGT
# -> Out edge: ATGGG
# -> Out edge: ATGGA
# -> Out edge: ATGGC
# -> In edge: AAATG
# -> In edge: TAATG
# -> In edge: GAATG
# -> In edge: CAATG
# Vertex: GACCG, coverage: 6
# -> Out edge: ACCGT
# -> Out edge: ACCGC
# -> Out edge: ACCGG
# -> Out edge: ACCGA
# -> In edge: TGACC
# -> In edge: AGACC
# Vertex: TTTTC, coverage: 377
# -> Out edge: TTTCA
# -> Out edge: TTTCG
# -> Out edge: TTTCT
# -> Out edge: TTTCC
# -> In edge: GTTTT
# -> In edge: CTTTT
# -> In edge: TTTTT
# -> In edge: ATTTT
# Vertex: AAATT, coverage: 478
# -> Out edge: AATTC
# -> Out edge: AATTT
# -> Out edge: AATTG
# -> Out edge: AATTA
# -> In edge: AAAAT
# -> In edge: CAAAT
# -> In edge: GAAAT
# -> In edge: TAAAT
# Vertex: CCGGT, coverage: 11
# -> Out edge: CGGTT
# -> Out edge: CGGTG
# -> Out edge: CGGTA
# -> In edge: TCCGG
# -> In edge: GCCGG
# -> In edge: CCCGG
# -> In edge: ACCGG
# Vertex: ATCGC, coverage: 7
# -> Out edge: TCGCA
# -> Out edge: TCGCT
# -> In edge: GATCG
# -> In edge: AATCG
# -> In edge: CATCG
# Vertex: GTAGA, coverage: 199
# -> Out edge: TAGAA
# -> Out edge: TAGAG
# -> Out edge: TAGAT
# -> Out edge: TAGAC
# -> In edge: GGTAG
# -> In edge: CGTAG
# -> In edge: TGTAG
# -> In edge: AGTAG
# Vertex: CGGCG, coverage: 103
# -> Out edge: GGCGA
# -> Out edge: GGCGG
# -> Out edge: GGCGC
# -> Out edge: GGCGT
# -> In edge: ACGGC
# -> In edge: TCGGC
# -> In edge: GCGGC
# -> In edge: CCGGC
# Vertex: GACGG, coverage: 283
# -> Out edge: ACGGT
# -> Out edge: ACGGG
# -> Out edge: ACGGA
# -> Out edge: ACGGC
# -> In edge: AGACG
# -> In edge: GGACG
# -> In edge: TGACG
# -> In edge: CGACG
# Vertex: GCGGT, coverage: 463
# -> Out edge: CGGTC
# -> Out edge: CGGTT
# -> Out edge: CGGTG
# -> Out edge: CGGTA
# -> In edge: TGCGG
# -> In edge: AGCGG
# -> In edge: GGCGG
# -> In edge: CGCGG
# Vertex: TCGCG, coverage: 11
# -> Out edge: CGCGC
# -> Out edge: CGCGT
# -> Out edge: CGCGA
# -> Out edge: CGCGG
# -> In edge: TTCGC
# -> In edge: GTCGC
# -> In edge: CTCGC
# Vertex: GACTC, coverage: 287
# -> Out edge: ACTCT
# -> Out edge: ACTCG
# -> Out edge: ACTCC
# -> Out edge: ACTCA
# -> In edge: CGACT
# -> In edge: TGACT
# -> In edge: GGACT
# -> In edge: AGACT
# Vertex: GGTAG, coverage: 251
# -> Out edge: GTAGA
# -> Out edge: GTAGG
# -> Out edge: GTAGT
# -> Out edge: GTAGC
# -> In edge: TGGTA
# -> In edge: CGGTA
# -> In edge: AGGTA
# -> In edge: GGGTA
# Vertex: AATTG, coverage: 384
# -> Out edge: ATTGT
# -> Out edge: ATTGG
# -> Out edge: ATTGA
# -> Out edge: ATTGC
# -> In edge: CAATT
# -> In edge: GAATT
# -> In edge: AAATT
# -> In edge: TAATT
# Vertex: GAGCA, coverage: 209
# -> Out edge: AGCAG
# -> Out edge: AGCAC
# -> Out edge: AGCAT
# -> Out edge: AGCAA
# -> In edge: TGAGC
# -> In edge: CGAGC
# -> In edge: GGAGC
# -> In edge: AGAGC
# Vertex: CGAGC, coverage: 100
# -> Out edge: GAGCT
# -> Out edge: GAGCG
# -> Out edge: GAGCA
# -> Out edge: GAGCC
# -> In edge: TCGAG
# -> In edge: ACGAG
# -> In edge: CCGAG
# -> In edge: GCGAG
# Vertex: GACGT, coverage: 285
# -> Out edge: ACGTC
# -> Out edge: ACGTT
# -> Out edge: ACGTA
# -> Out edge: ACGTG
# -> In edge: AGACG
# -> In edge: GGACG
# -> In edge: TGACG
# -> In edge: CGACG
# Vertex: GCGCC, coverage: 192
# -> Out edge: CGCCC
# -> Out edge: CGCCT
# -> Out edge: CGCCG
# -> Out edge: CGCCA
# -> In edge: AGCGC
# -> In edge: TGCGC
# -> In edge: GGCGC
# -> In edge: CGCGC
# Vertex: GCGTG, coverage: 9
# -> Out edge: CGTGA
# -> Out edge: CGTGT
# -> Out edge: CGTGC
# -> In edge: AGCGT
# -> In edge: TGCGT
# -> In edge: GGCGT
# Vertex: GCGAG, coverage: 375
# -> Out edge: CGAGC
# -> Out edge: CGAGG
# -> Out edge: CGAGA
# -> Out edge: CGAGT
# -> In edge: GGCGA
# -> In edge: TGCGA
# -> In edge: CGCGA
# -> In edge: AGCGA
# Vertex: GTCTA, coverage: 375
# -> Out edge: TCTAC
# -> Out edge: TCTAT
# -> Out edge: TCTAG
# -> Out edge: TCTAA
# -> In edge: TGTCT
# -> In edge: GGTCT
# -> In edge: AGTCT
# -> In edge: CGTCT
# Vertex: GGGGG, coverage: 199
# -> Out edge: GGGGG
# -> Out edge: GGGGC
# -> Out edge: GGGGT
# -> Out edge: GGGGA
# -> In edge: GGGGG
# -> In edge: TGGGG
# -> In edge: AGGGG
# -> In edge: CGGGG
# Vertex: CACCG, coverage: 9
# -> Out edge: ACCGT
# -> Out edge: ACCGC
# -> Out edge: ACCGA
# -> In edge: ACACC
# -> In edge: CCACC
# -> In edge: GCACC
# Vertex: AACCG, coverage: 10
# -> Out edge: ACCGC
# -> Out edge: ACCGG
# -> Out edge: ACCGA
# -> In edge: TAACC
# -> In edge: GAACC
# -> In edge: CAACC
# -> In edge: AAACC
# Vertex: AGCCG, coverage: 103
# -> Out edge: GCCGC
# -> Out edge: GCCGA
# -> Out edge: GCCGG
# -> Out edge: GCCGT
# -> In edge: CAGCC
# -> In edge: TAGCC
# -> In edge: GAGCC
# -> In edge: AAGCC
# Vertex: GTCTG, coverage: 203
# -> Out edge: TCTGA
# -> Out edge: TCTGG
# -> Out edge: TCTGT
# -> Out edge: TCTGC
# -> In edge: TGTCT
# -> In edge: GGTCT
# -> In edge: AGTCT
# -> In edge: CGTCT
# Vertex: ACATG, coverage: 192
# -> Out edge: CATGT
# -> Out edge: CATGA
# -> Out edge: CATGC
# -> Out edge: CATGG
# -> In edge: GACAT
# -> In edge: AACAT
# -> In edge: CACAT
# -> In edge: TACAT
# Vertex: CTAAG, coverage: 108
# -> Out edge: TAAGG
# -> Out edge: TAAGT
# -> Out edge: TAAGC
# -> Out edge: TAAGA
# -> In edge: CCTAA
# -> In edge: GCTAA
# -> In edge: TCTAA
# -> In edge: ACTAA
# Vertex: AGATT, coverage: 477
# -> Out edge: GATTG
# -> Out edge: GATTA
# -> Out edge: GATTC
# -> Out edge: GATTT
# -> In edge: AAGAT
# -> In edge: CAGAT
# -> In edge: GAGAT
# -> In edge: TAGAT
# Vertex: AGAAG, coverage: 1105
# -> Out edge: GAAGA
# -> Out edge: GAAGG
# -> Out edge: GAAGT
# -> Out edge: GAAGC
# -> In edge: GAGAA
# -> In edge: TAGAA
# -> In edge: AAGAA
# -> In edge: CAGAA
# Vertex: CTGTC, coverage: 14
# -> Out edge: TGTCT
# -> Out edge: TGTCA
# -> Out edge: TGTCG
# -> Out edge: TGTCC
# -> In edge: ACTGT
# -> In edge: CCTGT
# -> In edge: TCTGT
# -> In edge: GCTGT
# Vertex: TACTC, coverage: 103
# -> Out edge: ACTCT
# -> Out edge: ACTCG
# -> Out edge: ACTCC
# -> Out edge: ACTCA
# -> In edge: TTACT
# -> In edge: GTACT
# -> In edge: ATACT
# Vertex: AGTCA, coverage: 374
# -> Out edge: GTCAG
# -> Out edge: GTCAA
# -> Out edge: GTCAT
# -> Out edge: GTCAC
# -> In edge: TAGTC
# -> In edge: AAGTC
# -> In edge: GAGTC
# -> In edge: CAGTC
# Vertex: AAGAA, coverage: 929
# -> Out edge: AGAAC
# -> Out edge: AGAAA
# -> Out edge: AGAAG
# -> Out edge: AGAAT
# -> In edge: GAAGA
# -> In edge: CAAGA
# -> In edge: TAAGA
# -> In edge: AAAGA
# Vertex: CTCGA, coverage: 106
# -> Out edge: TCGAT
# -> Out edge: TCGAG
# -> Out edge: TCGAA
# -> Out edge: TCGAC
# -> In edge: TCTCG
# -> In edge: ACTCG
# -> In edge: CCTCG
# -> In edge: GCTCG
# Vertex: CCTAC, coverage: 377
# -> Out edge: CTACA
# -> Out edge: CTACC
# -> Out edge: CTACG
# -> Out edge: CTACT
# -> In edge: CCCTA
# -> In edge: ACCTA
# -> In edge: GCCTA
# -> In edge: TCCTA
# Vertex: GATGC, coverage: 110
# -> Out edge: ATGCG
# -> Out edge: ATGCA
# -> Out edge: ATGCT
# -> Out edge: ATGCC
# -> In edge: GGATG
# -> In edge: AGATG
# -> In edge: CGATG
# -> In edge: TGATG
# Vertex: ACCAT, coverage: 13
# -> Out edge: CCATC
# -> Out edge: CCATA
# -> Out edge: CCATT
# -> Out edge: CCATG
# -> In edge: TACCA
# -> In edge: AACCA
# -> In edge: GACCA
# -> In edge: CACCA
# Vertex: AGGCC, coverage: 519
# -> Out edge: GGCCT
# -> Out edge: GGCCC
# -> Out edge: GGCCG
# -> Out edge: GGCCA
# -> In edge: TAGGC
# -> In edge: GAGGC
# -> In edge: AAGGC
# -> In edge: CAGGC
# Vertex: CGCTC, coverage: 6
# -> Out edge: GCTCC
# -> Out edge: GCTCG
# -> Out edge: GCTCT
# -> In edge: GCGCT
# -> In edge: TCGCT
# -> In edge: CCGCT
# -> In edge: ACGCT
# Vertex: TACAT, coverage: 197
# -> Out edge: ACATA
# -> Out edge: ACATG
# -> Out edge: ACATC
# -> Out edge: ACATT
# -> In edge: CTACA
# -> In edge: TTACA
# -> In edge: ATACA
# -> In edge: GTACA
# Vertex: GAATA, coverage: 483
# -> Out edge: AATAC
# -> Out edge: AATAG
# -> Out edge: AATAT
# -> Out edge: AATAA
# -> In edge: GGAAT
# -> In edge: TGAAT
# -> In edge: AGAAT
# -> In edge: CGAAT
# Vertex: GTCAG, coverage: 294
# -> Out edge: TCAGG
# -> Out edge: TCAGT
# -> Out edge: TCAGA
# -> Out edge: TCAGC
# -> In edge: TGTCA
# -> In edge: CGTCA
# -> In edge: AGTCA
# -> In edge: GGTCA
# Vertex: GAAGT, coverage: 749
# -> Out edge: AAGTG
# -> Out edge: AAGTA
# -> Out edge: AAGTC
# -> Out edge: AAGTT
# -> In edge: CGAAG
# -> In edge: TGAAG
# -> In edge: AGAAG
# -> In edge: GGAAG
# Vertex: TTACA, coverage: 104
# -> Out edge: TACAA
# -> Out edge: TACAC
# -> Out edge: TACAG
# -> Out edge: TACAT
# -> In edge: TTTAC
# -> In edge: ATTAC
# -> In edge: GTTAC
# -> In edge: CTTAC
# Vertex: GTGAG, coverage: 479
# -> Out edge: TGAGG
# -> Out edge: TGAGC
# -> Out edge: TGAGT
# -> Out edge: TGAGA
# -> In edge: CGTGA
# -> In edge: AGTGA
# -> In edge: TGTGA
# -> In edge: GGTGA
# Vertex: TCCCT, coverage: 11
# -> Out edge: CCCTA
# -> Out edge: CCCTT
# -> Out edge: CCCTG
# -> In edge: TTCCC
# -> In edge: CTCCC
# -> In edge: ATCCC
# -> In edge: GTCCC
# Vertex: ACCTA, coverage: 109
# -> Out edge: CCTAA
# -> Out edge: CCTAG
# -> Out edge: CCTAC
# -> Out edge: CCTAT
# -> In edge: GACCT
# -> In edge: TACCT
# -> In edge: AACCT
# -> In edge: CACCT
# Vertex: GGAAC, coverage: 104
# -> Out edge: GAACT
# -> Out edge: GAACG
# -> Out edge: GAACC
# -> Out edge: GAACA
# -> In edge: CGGAA
# -> In edge: GGGAA
# -> In edge: AGGAA
# -> In edge: TGGAA
# Vertex: GCTCT, coverage: 106
# -> Out edge: CTCTG
# -> Out edge: CTCTA
# -> Out edge: CTCTC
# -> In edge: CGCTC
# -> In edge: AGCTC
# -> In edge: GGCTC
# -> In edge: TGCTC
# Vertex: GCTTG, coverage: 291
# -> Out edge: CTTGG
# -> Out edge: CTTGT
# -> Out edge: CTTGA
# -> Out edge: CTTGC
# -> In edge: AGCTT
# -> In edge: TGCTT
# -> In edge: CGCTT
# -> In edge: GGCTT
# Vertex: GGGAA, coverage: 363
# -> Out edge: GGAAT
# -> Out edge: GGAAC
# -> Out edge: GGAAA
# -> Out edge: GGAAG
# -> In edge: TGGGA
# -> In edge: CGGGA
# -> In edge: AGGGA
# -> In edge: GGGGA
# Vertex: CGCCG, coverage: 194
# -> Out edge: GCCGC
# -> Out edge: GCCGA
# -> Out edge: GCCGG
# -> Out edge: GCCGT
# -> In edge: CCGCC
# -> In edge: ACGCC
# -> In edge: TCGCC
# -> In edge: GCGCC
# Vertex: TTTAT, coverage: 199
# -> Out edge: TTATG
# -> Out edge: TTATT
# -> Out edge: TTATA
# -> Out edge: TTATC
# -> In edge: TTTTA
# -> In edge: ATTTA
# -> In edge: GTTTA
# -> In edge: CTTTA
# Vertex: AACGA, coverage: 199
# -> Out edge: ACGAC
# -> Out edge: ACGAT
# -> Out edge: ACGAA
# -> Out edge: ACGAG
# -> In edge: TAACG
# -> In edge: AAACG
# -> In edge: GAACG
# -> In edge: CAACG
# Vertex: AGGGT, coverage: 474
# -> Out edge: GGGTG
# -> Out edge: GGGTC
# -> Out edge: GGGTA
# -> Out edge: GGGTT
# -> In edge: GAGGG
# -> In edge: CAGGG
# -> In edge: AAGGG
# -> In edge: TAGGG
# Vertex: AATTT, coverage: 479
# -> Out edge: ATTTA
# -> Out edge: ATTTG
# -> Out edge: ATTTT
# -> Out edge: ATTTC
# -> In edge: CAATT
# -> In edge: GAATT
# -> In edge: AAATT
# -> In edge: TAATT
# Vertex: CAGAG, coverage: 594
# -> Out edge: AGAGA
# -> Out edge: AGAGC
# -> Out edge: AGAGT
# -> Out edge: AGAGG
# -> In edge: GCAGA
# -> In edge: CCAGA
# -> In edge: ACAGA
# -> In edge: TCAGA
# Vertex: TTGCC, coverage: 284
# -> Out edge: TGCCT
# -> Out edge: TGCCG
# -> Out edge: TGCCC
# -> Out edge: TGCCA
# -> In edge: TTTGC
# -> In edge: ATTGC
# -> In edge: CTTGC
# -> In edge: GTTGC
# Vertex: GGAAT, coverage: 481
# -> Out edge: GAATC
# -> Out edge: GAATT
# -> Out edge: GAATG
# -> Out edge: GAATA
# -> In edge: GGGAA
# -> In edge: CGGAA
# -> In edge: AGGAA
# -> In edge: TGGAA
# Vertex: ATGCA, coverage: 193
# -> Out edge: TGCAG
# -> Out edge: TGCAT
# -> Out edge: TGCAC
# -> In edge: AATGC
# -> In edge: GATGC
# -> In edge: TATGC
# -> In edge: CATGC
# Vertex: GTGCC, coverage: 16
# -> Out edge: TGCCT
# -> Out edge: TGCCG
# -> Out edge: TGCCC
# -> Out edge: TGCCA
# -> In edge: AGTGC
# -> In edge: GGTGC
# -> In edge: CGTGC
# Vertex: TAACA, coverage: 563
# -> Out edge: AACAA
# -> Out edge: AACAT
# -> Out edge: AACAC
# -> Out edge: AACAG
# -> In edge: GTAAC
# -> In edge: ATAAC
# -> In edge: TTAAC
# -> In edge: CTAAC
# Vertex: AAGGC, coverage: 754
# -> Out edge: AGGCC
# -> Out edge: AGGCT
# -> Out edge: AGGCA
# -> Out edge: AGGCG
# -> In edge: GAAGG
# -> In edge: TAAGG
# -> In edge: CAAGG
# -> In edge: AAAGG
# Vertex: CTGTT, coverage: 367
# -> Out edge: TGTTA
# -> Out edge: TGTTC
# -> Out edge: TGTTG
# -> Out edge: TGTTT
# -> In edge: ACTGT
# -> In edge: CCTGT
# -> In edge: GCTGT
# -> In edge: TCTGT
# Vertex: ATTCT, coverage: 372
# -> Out edge: TTCTG
# -> Out edge: TTCTT
# -> Out edge: TTCTC
# -> Out edge: TTCTA
# -> In edge: AATTC
# -> In edge: TATTC
# -> In edge: GATTC
# -> In edge: CATTC
# Vertex: ACGCA, coverage: 197
# -> Out edge: CGCAA
# -> Out edge: CGCAT
# -> Out edge: CGCAC
# -> Out edge: CGCAG
# -> In edge: AACGC
# -> In edge: GACGC
# -> In edge: TACGC
# -> In edge: CACGC
# Vertex: TTAGT, coverage: 196
# -> Out edge: TAGTC
# -> Out edge: TAGTA
# -> Out edge: TAGTG
# -> Out edge: TAGTT
# -> In edge: GTTAG
# -> In edge: ATTAG
# -> In edge: CTTAG
# -> In edge: TTTAG
# Vertex: CACCA, coverage: 259
# -> Out edge: ACCAG
# -> Out edge: ACCAC
# -> Out edge: ACCAT
# -> Out edge: ACCAA
# -> In edge: ACACC
# -> In edge: CCACC
# -> In edge: TCACC
# -> In edge: GCACC
# Vertex: GGAGC, coverage: 186
# -> Out edge: GAGCT
# -> Out edge: GAGCA
# -> Out edge: GAGCG
# -> Out edge: GAGCC
# -> In edge: GGGAG
# -> In edge: AGGAG
# -> In edge: TGGAG
# -> In edge: CGGAG
# Vertex: ACGAG, coverage: 381
# -> Out edge: CGAGC
# -> Out edge: CGAGG
# -> Out edge: CGAGA
# -> Out edge: CGAGT
# -> In edge: GACGA
# -> In edge: AACGA
# -> In edge: TACGA
# -> In edge: CACGA
# Vertex: ACTGA, coverage: 473
# -> Out edge: CTGAG
# -> Out edge: CTGAC
# -> Out edge: CTGAA
# -> Out edge: CTGAT
# -> In edge: CACTG
# -> In edge: TACTG
# -> In edge: AACTG
# -> In edge: GACTG
# Vertex: CAAAA, coverage: 750
# -> Out edge: AAAAT
# -> Out edge: AAAAG
# -> Out edge: AAAAC
# -> Out edge: AAAAA
# -> In edge: ACAAA
# -> In edge: TCAAA
# -> In edge: GCAAA
# -> In edge: CCAAA
# Vertex: CGTGG, coverage: 101
# -> Out edge: GTGGT
# -> Out edge: GTGGA
# -> Out edge: GTGGC
# -> Out edge: GTGGG
# -> In edge: TCGTG
# -> In edge: ACGTG
# -> In edge: CCGTG
# Vertex: ATTCA, coverage: 107
# -> Out edge: TTCAC
# -> Out edge: TTCAA
# -> Out edge: TTCAG
# -> In edge: CATTC
# -> In edge: TATTC
# -> In edge: GATTC
# -> In edge: AATTC
# Vertex: ATATT, coverage: 463
# -> Out edge: TATTT
# -> Out edge: TATTC
# -> Out edge: TATTG
# -> Out edge: TATTA
# -> In edge: TATAT
# -> In edge: CATAT
# -> In edge: AATAT
# -> In edge: GATAT
# Vertex: CCACT, coverage: 200
# -> Out edge: CACTG
# -> Out edge: CACTC
# -> Out edge: CACTA
# -> Out edge: CACTT
# -> In edge: TCCAC
# -> In edge: ACCAC
# -> In edge: GCCAC
# -> In edge: CCCAC
# Vertex: AGTCG, coverage: 10
# -> Out edge: GTCGG
# -> Out edge: GTCGT
# -> Out edge: GTCGA
# -> Out edge: GTCGC
# -> In edge: TAGTC
# -> In edge: CAGTC
# -> In edge: GAGTC
# Vertex: ATTCG, coverage: 99
# -> Out edge: TTCGC
# -> Out edge: TTCGG
# -> Out edge: TTCGA
# -> Out edge: TTCGT
# -> In edge: AATTC
# -> In edge: TATTC
# -> In edge: GATTC
# -> In edge: CATTC
# Vertex: TGAAA, coverage: 483
# -> Out edge: GAAAG
# -> Out edge: GAAAA
# -> Out edge: GAAAT
# -> Out edge: GAAAC
# -> In edge: TTGAA
# -> In edge: GTGAA
# -> In edge: CTGAA
# -> In edge: ATGAA
# Vertex: AAGGA, coverage: 399
# -> Out edge: AGGAC
# -> Out edge: AGGAA
# -> Out edge: AGGAT
# -> Out edge: AGGAG
# -> In edge: GAAGG
# -> In edge: TAAGG
# -> In edge: CAAGG
# -> In edge: AAAGG
# Vertex: CCTTA, coverage: 197
# -> Out edge: CTTAA
# -> Out edge: CTTAG
# -> Out edge: CTTAT
# -> Out edge: CTTAC
# -> In edge: TCCTT
# -> In edge: CCCTT
# -> In edge: ACCTT
# -> In edge: GCCTT
# Vertex: TTTTA, coverage: 15
# -> Out edge: TTTAC
# -> Out edge: TTTAA
# -> Out edge: TTTAT
# -> Out edge: TTTAG
# -> In edge: GTTTT
# -> In edge: CTTTT
# -> In edge: TTTTT
# -> In edge: ATTTT
# Vertex: CCACC, coverage: 539
# -> Out edge: CACCT
# -> Out edge: CACCG
# -> Out edge: CACCC
# -> Out edge: CACCA
# -> In edge: TCCAC
# -> In edge: ACCAC
# -> In edge: GCCAC
# -> In edge: CCCAC
# Vertex: TAACT, coverage: 567
# -> Out edge: AACTG
# -> Out edge: AACTT
# -> Out edge: AACTC
# -> Out edge: AACTA
# -> In edge: GTAAC
# -> In edge: ATAAC
# -> In edge: CTAAC
# -> In edge: TTAAC
# Vertex: TTCTA, coverage: 190
# -> Out edge: TCTAC
# -> Out edge: TCTAT
# -> Out edge: TCTAG
# -> Out edge: TCTAA
# -> In edge: ATTCT
# -> In edge: CTTCT
# -> In edge: GTTCT
# -> In edge: TTTCT
# Vertex: TAGTG, coverage: 198
# -> Out edge: AGTGC
# -> Out edge: AGTGT
# -> Out edge: AGTGG
# -> Out edge: AGTGA
# -> In edge: TTAGT
# -> In edge: CTAGT
# -> In edge: ATAGT
# -> In edge: GTAGT
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-72906163c35a> in <module>()
#     110             print('-> In edge: {}'.format(e))
#     111
# --> 112     my_graph.Graph_viz('Graph.dot', full=False)
#
# <ipython-input-2-72906163c35a> in Graph_viz(self, PathToWrite, full)
#      62     def Graph_viz(self, PathToWrite, full):
#      63
# ---> 64         self.graph =  Graph(comment='assembly')
#      65
#      66         if full:
#
# TypeError: __init__() got an unexpected keyword argument 'comment'
